# %%
import numpy as np
import pandas as pd
import itertools

# %%
df = pd.read_csv('modified.csv')

# %%
df.sample(5)
# Out:
#            source        location  \
# 6832  internshala  work_from_home
# 1053  internshala  work_from_home
# 2783  internshala  work_from_home
# 4577  internshala  work_from_home
# 1032  internshala  work_from_home
#
#                                                job_link  \
# 6832  https://internshala.com/internship/detail/cont...
# 1053  https://internshala.com/internship/detail/busi...
# 2783  https://internshala.com/internship/details/dev...
# 4577  https://internshala.com/internship/detail/busi...
# 1032  https://internshala.com/internship/details/soc...
#
#                          job_title                        company_name  \
# 6832               Content Writing                             Nearbuy
# 1053  Business Development (Sales)  Toppr Technologies Private Limited
# 2783           Development Support                  Child Rights & You
# 4577  Business Development (Sales)           Delhivery Private Limited
# 1032        Social Media Marketing                    HCL Technologies
#
#                                    description_headings  \
# 6832  ['About Nearbuy', ' About the work from home j...
# 1053  ['About Toppr Technologies Private Limited', '...
# 2783  ['About Child Rights & You', ' About the work ...
# 4577  ['About Delhivery Private Limited', ' About th...
# 1032  ['About HCL Technologies', ' About the work fr...
#
#                                             description   start_date  \
# 6832  About Nearbuy        \r\n\r\nhttps://www.nearb...  immediately
# 1053  About Toppr Technologies Private Limited      ...  immediately
# 2783  About Child Rights & You        \r\n\r\nhttps:...  immediately
# 4577  About Delhivery Private Limited        \r\n\r\...  immediately
# 1032  About HCL Technologies        \r\n\r\nhttps://...  immediately
#
#       duration                    stipend  last_date           job_mode  \
# 6832  6 Months               10000 /month  29 Jun 20  Part time allowed
# 1053  3 Months  8000 /month +  Incentives  23 Jun 20  Part time allowed
# 2783  2 Months                     Unpaid  17 Jun 20  Part time allowed
# 4577  2 Months               10000 /month  18 Jun 20  Part time allowed
# 1032   1 Month                3500 /month   2 Jun 20  Part time allowed
#
#                      skills  \
# 6832  Blogging  Copywriting
# 1053             Salesforce
# 2783                    NaN
# 4577                    NaN
# 1032                    NaN
#
#                                          no_of_openings  months_duration  \
# 6832                                                  1                6
# 1053                                                  4                3
# 2783                                                100                2
# 4577                                                 10                2
# 1032  20    \r\n\r\n\r\n\r\n                    Clos...                1
#
#      stipend_month incentives
# 6832         10000         No
# 1053          8000        Yes
# 2783           NaN         No
# 4577         10000         No
# 1032          3500         No

# %%
df['skills'].size
# Out:
# 8115

# %%
df['skills'].isnull().sum()
# Out:
# 4531

# %% [markdown]
# #### here out of 8115 there are 4531 null values

# %%
a = df['skills'][5]

# %%
a
# Out:
# 'MS Office  Adobe Photoshop  Magento  English Proficiency  Spoken   English Proficiency  Written'

# %%
type(a)
# Out:
# str

# %%
[i.strip() for i in a.split("  ")]
# Out:
# ['MS Office',
#  'Adobe Photoshop',
#  'Magento',
#  'English Proficiency',
#  'Spoken',
#  'English Proficiency',
#  'Written']

# %%
df[df['skills'].notnull()]['skills']
# Out:
# 0                           Java  Python  Data Structures
# 1                                   Blogging  Copywriting
# 2                                               MS Office
# 3                                                MS Excel
# 4       Adobe Photoshop  Adobe Illustrator  Video Editing
#                               ...
# 8107                C  NET  ANSYS  Artifical Intelligence
# 8109                    PHP  JavaScript  Magento  LARAVEL
# 8110                                    Digital Marketing
# 8113                                               Python
# 8114                                              Biology
# Name: skills, Length: 3584, dtype: object

# %%
records = []
for i in df[df['skills'].notnull()]['skills']:
    records.append([j.strip() for j in i.split("  ")])

# %%
records
# Out:
# [['Java', 'Python', 'Data Structures'],
#  ['Blogging', 'Copywriting'],
#  ['MS Office'],
#  ['MS Excel'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Video Editing'],
#  ['MS Office',
#   'Adobe Photoshop',
#   'Magento',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe XD'],
#  ['Salesforce'],
#  ['PHP',
#   'HTML',
#   'CSS',
#   'Adobe Dreamweaver',
#   'Search Engine Optimization',
#   'SEO'],
#  ['English Proficiency',
#   'Spoken',
#   'Hindi Proficiency',
#   'Spoken',
#   'Telugu Proficiency',
#   'Spoken'],
#  ['English Proficiency', 'Written'],
#  ['MS Office',
#   'MS Excel',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Search Engine Optimization',
#   'SEO',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['English Proficiency', 'Written'],
#  ['MS Office',
#   'MS Word',
#   'MS PowerPoint',
#   'MS Excel',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe After Effects'],
#  ['MS Office',
#   'MS Word',
#   'MS PowerPoint',
#   'Search Engine Optimization',
#   'SEO',
#   'MS Excel'],
#  ['Java', 'Python', 'Data Structures'],
#  ['Blogging', 'Copywriting'],
#  ['MS Office'],
#  ['MS Excel'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Video Editing'],
#  ['MS Office',
#   'Adobe Photoshop',
#   'Magento',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe XD'],
#  ['Salesforce'],
#  ['PHP',
#   'HTML',
#   'CSS',
#   'Adobe Dreamweaver',
#   'Search Engine Optimization',
#   'SEO'],
#  ['English Proficiency',
#   'Spoken',
#   'Hindi Proficiency',
#   'Spoken',
#   'Telugu Proficiency',
#   'Spoken'],
#  ['English Proficiency', 'Written'],
#  ['MS Office',
#   'MS Excel',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Search Engine Optimization',
#   'SEO',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['English Proficiency', 'Written'],
#  ['MS Office',
#   'MS Word',
#   'MS PowerPoint',
#   'MS Excel',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe After Effects'],
#  ['MS Office',
#   'MS Word',
#   'MS PowerPoint',
#   'Search Engine Optimization',
#   'SEO',
#   'MS Excel'],
#  ['Java', 'Python', 'Data Structures'],
#  ['Blogging', 'Copywriting'],
#  ['MS Office'],
#  ['MS Excel'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Video Editing'],
#  ['MS Office',
#   'Adobe Photoshop',
#   'Magento',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe XD'],
#  ['Salesforce'],
#  ['PHP',
#   'HTML',
#   'CSS',
#   'Adobe Dreamweaver',
#   'Search Engine Optimization',
#   'SEO'],
#  ['English Proficiency',
#   'Spoken',
#   'Hindi Proficiency',
#   'Spoken',
#   'Telugu Proficiency',
#   'Spoken'],
#  ['English Proficiency', 'Written'],
#  ['MS Office',
#   'MS Excel',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Search Engine Optimization',
#   'SEO',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['English Proficiency', 'Written'],
#  ['MS Office',
#   'MS Word',
#   'MS PowerPoint',
#   'MS Excel',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe After Effects'],
#  ['MS Office',
#   'MS Word',
#   'MS PowerPoint',
#   'Search Engine Optimization',
#   'SEO',
#   'MS Excel'],
#  ['Java', 'Python', 'Data Structures'],
#  ['Blogging', 'Copywriting'],
#  ['MS Office'],
#  ['MS Excel'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Video Editing'],
#  ['MS Office',
#   'Adobe Photoshop',
#   'Magento',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe XD'],
#  ['Salesforce'],
#  ['PHP',
#   'HTML',
#   'CSS',
#   'Adobe Dreamweaver',
#   'Search Engine Optimization',
#   'SEO'],
#  ['English Proficiency',
#   'Spoken',
#   'Hindi Proficiency',
#   'Spoken',
#   'Telugu Proficiency',
#   'Spoken'],
#  ['English Proficiency', 'Written'],
#  ['MS Office',
#   'MS Excel',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Search Engine Optimization',
#   'SEO',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['English Proficiency', 'Written'],
#  ['MS Office',
#   'MS Word',
#   'MS PowerPoint',
#   'MS Excel',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe After Effects'],
#  ['MS Office',
#   'MS Word',
#   'MS PowerPoint',
#   'Search Engine Optimization',
#   'SEO',
#   'MS Excel'],
#  ['Java', 'Python', 'Data Structures'],
#  ['Blogging', 'Copywriting'],
#  ['MS Office'],
#  ['MS Excel'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Video Editing'],
#  ['MS Office',
#   'Adobe Photoshop',
#   'Magento',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe XD'],
#  ['Salesforce'],
#  ['PHP',
#   'HTML',
#   'CSS',
#   'Adobe Dreamweaver',
#   'Search Engine Optimization',
#   'SEO'],
#  ['English Proficiency',
#   'Spoken',
#   'Hindi Proficiency',
#   'Spoken',
#   'Telugu Proficiency',
#   'Spoken'],
#  ['English Proficiency', 'Written'],
#  ['MS Office',
#   'MS Excel',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Search Engine Optimization',
#   'SEO',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['English Proficiency', 'Written'],
#  ['MS Office',
#   'MS Word',
#   'MS PowerPoint',
#   'MS Excel',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe After Effects'],
#  ['MS Office',
#   'MS Word',
#   'MS PowerPoint',
#   'Search Engine Optimization',
#   'SEO',
#   'MS Excel'],
#  ['Java', 'Python', 'Data Structures'],
#  ['Blogging', 'Copywriting'],
#  ['MS Office'],
#  ['MS Excel'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Video Editing'],
#  ['MS Office',
#   'Adobe Photoshop',
#   'Magento',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe XD'],
#  ['Salesforce'],
#  ['PHP',
#   'HTML',
#   'CSS',
#   'Adobe Dreamweaver',
#   'Search Engine Optimization',
#   'SEO'],
#  ['English Proficiency',
#   'Spoken',
#   'Hindi Proficiency',
#   'Spoken',
#   'Telugu Proficiency',
#   'Spoken'],
#  ['English Proficiency', 'Written'],
#  ['MS Office',
#   'MS Excel',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Search Engine Optimization',
#   'SEO',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['English Proficiency', 'Written'],
#  ['MS Office',
#   'MS Word',
#   'MS PowerPoint',
#   'MS Excel',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe After Effects'],
#  ['MS Office',
#   'MS Word',
#   'MS PowerPoint',
#   'Search Engine Optimization',
#   'SEO',
#   'MS Excel'],
#  ['Java', 'Python', 'Data Structures'],
#  ['Blogging', 'Copywriting'],
#  ['MS Office'],
#  ['MS Excel'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Video Editing'],
#  ['MS Office',
#   'Adobe Photoshop',
#   'Magento',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe XD'],
#  ['Salesforce'],
#  ['PHP',
#   'HTML',
#   'CSS',
#   'Adobe Dreamweaver',
#   'Search Engine Optimization',
#   'SEO'],
#  ['English Proficiency',
#   'Spoken',
#   'Hindi Proficiency',
#   'Spoken',
#   'Telugu Proficiency',
#   'Spoken'],
#  ['English Proficiency', 'Written'],
#  ['MS Office',
#   'MS Excel',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Search Engine Optimization',
#   'SEO',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['English Proficiency', 'Written'],
#  ['MS Office',
#   'MS Word',
#   'MS PowerPoint',
#   'MS Excel',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe After Effects'],
#  ['MS Office',
#   'MS Word',
#   'MS PowerPoint',
#   'Search Engine Optimization',
#   'SEO',
#   'MS Excel'],
#  ['Java', 'Python', 'Data Structures'],
#  ['Blogging', 'Copywriting'],
#  ['MS Office'],
#  ['MS Excel'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Video Editing'],
#  ['MS Office',
#   'Adobe Photoshop',
#   'Magento',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe XD'],
#  ['Salesforce'],
#  ['PHP',
#   'HTML',
#   'CSS',
#   'Adobe Dreamweaver',
#   'Search Engine Optimization',
#   'SEO'],
#  ['English Proficiency',
#   'Spoken',
#   'Hindi Proficiency',
#   'Spoken',
#   'Telugu Proficiency',
#   'Spoken'],
#  ['English Proficiency', 'Written'],
#  ['MS Office',
#   'MS Excel',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Search Engine Optimization',
#   'SEO',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['English Proficiency', 'Written'],
#  ['MS Office',
#   'MS Word',
#   'MS PowerPoint',
#   'MS Excel',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe After Effects'],
#  ['MS Office',
#   'MS Word',
#   'MS PowerPoint',
#   'Search Engine Optimization',
#   'SEO',
#   'MS Excel'],
#  ['Java', 'Python', 'Data Structures'],
#  ['Blogging', 'Copywriting'],
#  ['MS Office'],
#  ['MS Excel'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Video Editing'],
#  ['MS Office',
#   'Adobe Photoshop',
#   'Magento',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe XD'],
#  ['Salesforce'],
#  ['PHP',
#   'HTML',
#   'CSS',
#   'Adobe Dreamweaver',
#   'Search Engine Optimization',
#   'SEO'],
#  ['English Proficiency',
#   'Spoken',
#   'Hindi Proficiency',
#   'Spoken',
#   'Telugu Proficiency',
#   'Spoken'],
#  ['English Proficiency', 'Written'],
#  ['MS Office',
#   'MS Excel',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Search Engine Optimization',
#   'SEO',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['English Proficiency', 'Written'],
#  ['MS Office',
#   'MS Word',
#   'MS PowerPoint',
#   'MS Excel',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe After Effects'],
#  ['MS Office',
#   'MS Word',
#   'MS PowerPoint',
#   'Search Engine Optimization',
#   'SEO',
#   'MS Excel'],
#  ['Java', 'Python', 'Data Structures'],
#  ['Blogging', 'Copywriting'],
#  ['MS Office'],
#  ['MS Excel'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Video Editing'],
#  ['MS Office',
#   'Adobe Photoshop',
#   'Magento',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe XD'],
#  ['Salesforce'],
#  ['PHP',
#   'HTML',
#   'CSS',
#   'Adobe Dreamweaver',
#   'Search Engine Optimization',
#   'SEO'],
#  ['English Proficiency',
#   'Spoken',
#   'Hindi Proficiency',
#   'Spoken',
#   'Telugu Proficiency',
#   'Spoken'],
#  ['English Proficiency', 'Written'],
#  ['MS Office',
#   'MS Excel',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Search Engine Optimization',
#   'SEO',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['English Proficiency', 'Written'],
#  ['MS Office',
#   'MS Word',
#   'MS PowerPoint',
#   'MS Excel',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe After Effects'],
#  ['MS Office',
#   'MS Word',
#   'MS PowerPoint',
#   'Search Engine Optimization',
#   'SEO',
#   'MS Excel'],
#  ['Java', 'Python', 'Data Structures'],
#  ['Blogging', 'Copywriting'],
#  ['MS Office'],
#  ['MS Excel'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Video Editing'],
#  ['MS Office',
#   'Adobe Photoshop',
#   'Magento',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe XD'],
#  ['Salesforce'],
#  ['PHP',
#   'HTML',
#   'CSS',
#   'Adobe Dreamweaver',
#   'Search Engine Optimization',
#   'SEO'],
#  ['English Proficiency',
#   'Spoken',
#   'Hindi Proficiency',
#   'Spoken',
#   'Telugu Proficiency',
#   'Spoken'],
#  ['English Proficiency', 'Written'],
#  ['MS Office',
#   'MS Excel',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Search Engine Optimization',
#   'SEO',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['English Proficiency', 'Written'],
#  ['MS Office',
#   'MS Word',
#   'MS PowerPoint',
#   'MS Excel',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe After Effects'],
#  ['MS Office',
#   'MS Word',
#   'MS PowerPoint',
#   'Search Engine Optimization',
#   'SEO',
#   'MS Excel'],
#  ['Java', 'Python', 'Data Structures'],
#  ['Blogging', 'Copywriting'],
#  ['MS Office'],
#  ['MS Excel'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Video Editing'],
#  ['MS Office',
#   'Adobe Photoshop',
#   'Magento',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe XD'],
#  ['Salesforce'],
#  ['PHP',
#   'HTML',
#   'CSS',
#   'Adobe Dreamweaver',
#   'Search Engine Optimization',
#   'SEO'],
#  ['English Proficiency',
#   'Spoken',
#   'Hindi Proficiency',
#   'Spoken',
#   'Telugu Proficiency',
#   'Spoken'],
#  ['English Proficiency', 'Written'],
#  ['MS Office',
#   'MS Excel',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Search Engine Optimization',
#   'SEO',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['English Proficiency', 'Written'],
#  ['MS Office',
#   'MS Word',
#   'MS PowerPoint',
#   'MS Excel',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe After Effects'],
#  ['MS Office',
#   'MS Word',
#   'MS PowerPoint',
#   'Search Engine Optimization',
#   'SEO',
#   'MS Excel'],
#  ['Java', 'Python', 'Data Structures'],
#  ['Blogging', 'Copywriting'],
#  ['MS Office'],
#  ['MS Excel'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Video Editing'],
#  ['MS Office',
#   'Adobe Photoshop',
#   'Magento',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe XD'],
#  ['Salesforce'],
#  ['PHP',
#   'HTML',
#   'CSS',
#   'Adobe Dreamweaver',
#   'Search Engine Optimization',
#   'SEO'],
#  ['English Proficiency',
#   'Spoken',
#   'Hindi Proficiency',
#   'Spoken',
#   'Telugu Proficiency',
#   'Spoken'],
#  ['English Proficiency', 'Written'],
#  ['MS Office',
#   'MS Excel',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Search Engine Optimization',
#   'SEO',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['English Proficiency', 'Written'],
#  ['MS Office',
#   'MS Word',
#   'MS PowerPoint',
#   'MS Excel',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe After Effects'],
#  ['MS Office',
#   'MS Word',
#   'MS PowerPoint',
#   'Search Engine Optimization',
#   'SEO',
#   'MS Excel'],
#  ['Java', 'Python', 'Data Structures'],
#  ['Blogging', 'Copywriting'],
#  ['MS Office'],
#  ['MS Excel'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Video Editing'],
#  ['MS Office',
#   'Adobe Photoshop',
#   'Magento',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe XD'],
#  ['Salesforce'],
#  ['PHP',
#   'HTML',
#   'CSS',
#   'Adobe Dreamweaver',
#   'Search Engine Optimization',
#   'SEO'],
#  ['English Proficiency',
#   'Spoken',
#   'Hindi Proficiency',
#   'Spoken',
#   'Telugu Proficiency',
#   'Spoken'],
#  ['English Proficiency', 'Written'],
#  ['MS Office',
#   'MS Excel',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Search Engine Optimization',
#   'SEO',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['English Proficiency', 'Written'],
#  ['MS Office',
#   'MS Word',
#   'MS PowerPoint',
#   'MS Excel',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe After Effects'],
#  ['MS Office',
#   'MS Word',
#   'MS PowerPoint',
#   'Search Engine Optimization',
#   'SEO',
#   'MS Excel'],
#  ['Java', 'Python', 'Data Structures'],
#  ['Blogging', 'Copywriting'],
#  ['MS Office'],
#  ['MS Excel'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Video Editing'],
#  ['MS Office',
#   'Adobe Photoshop',
#   'Magento',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe XD'],
#  ['Salesforce'],
#  ['PHP',
#   'HTML',
#   'CSS',
#   'Adobe Dreamweaver',
#   'Search Engine Optimization',
#   'SEO'],
#  ['English Proficiency',
#   'Spoken',
#   'Hindi Proficiency',
#   'Spoken',
#   'Telugu Proficiency',
#   'Spoken'],
#  ['English Proficiency', 'Written'],
#  ['MS Office',
#   'MS Excel',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Search Engine Optimization',
#   'SEO',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['English Proficiency', 'Written'],
#  ['MS Office',
#   'MS Word',
#   'MS PowerPoint',
#   'MS Excel',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe After Effects'],
#  ['MS Office',
#   'MS Word',
#   'MS PowerPoint',
#   'Search Engine Optimization',
#   'SEO',
#   'MS Excel'],
#  ['Java', 'Python', 'Data Structures'],
#  ['Blogging', 'Copywriting'],
#  ['MS Office'],
#  ['MS Excel'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Video Editing'],
#  ['MS Office',
#   'Adobe Photoshop',
#   'Magento',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe XD'],
#  ['Salesforce'],
#  ['PHP',
#   'HTML',
#   'CSS',
#   'Adobe Dreamweaver',
#   'Search Engine Optimization',
#   'SEO'],
#  ['English Proficiency',
#   'Spoken',
#   'Hindi Proficiency',
#   'Spoken',
#   'Telugu Proficiency',
#   'Spoken'],
#  ['English Proficiency', 'Written'],
#  ['MS Office',
#   'MS Excel',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Search Engine Optimization',
#   'SEO',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['English Proficiency', 'Written'],
#  ['MS Office',
#   'MS Word',
#   'MS PowerPoint',
#   'MS Excel',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe After Effects'],
#  ['MS Office',
#   'MS Word',
#   'MS PowerPoint',
#   'Search Engine Optimization',
#   'SEO',
#   'MS Excel'],
#  ['Java', 'Python', 'Data Structures'],
#  ['Blogging', 'Copywriting'],
#  ['MS Office'],
#  ['MS Excel'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Video Editing'],
#  ['MS Office',
#   'Adobe Photoshop',
#   'Magento',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe XD'],
#  ['Salesforce'],
#  ['PHP',
#   'HTML',
#   'CSS',
#   'Adobe Dreamweaver',
#   'Search Engine Optimization',
#   'SEO'],
#  ['English Proficiency',
#   'Spoken',
#   'Hindi Proficiency',
#   'Spoken',
#   'Telugu Proficiency',
#   'Spoken'],
#  ['English Proficiency', 'Written'],
#  ['MS Office',
#   'MS Excel',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Search Engine Optimization',
#   'SEO',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['English Proficiency', 'Written'],
#  ['MS Office',
#   'MS Word',
#   'MS PowerPoint',
#   'MS Excel',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe After Effects'],
#  ['MS Office',
#   'MS Word',
#   'MS PowerPoint',
#   'Search Engine Optimization',
#   'SEO',
#   'MS Excel'],
#  ['Java', 'Python', 'Data Structures'],
#  ['Blogging', 'Copywriting'],
#  ['MS Office'],
#  ['MS Excel'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Video Editing'],
#  ['MS Office',
#   'Adobe Photoshop',
#   'Magento',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe XD'],
#  ['Salesforce'],
#  ['PHP',
#   'HTML',
#   'CSS',
#   'Adobe Dreamweaver',
#   'Search Engine Optimization',
#   'SEO'],
#  ['English Proficiency',
#   'Spoken',
#   'Hindi Proficiency',
#   'Spoken',
#   'Telugu Proficiency',
#   'Spoken'],
#  ['English Proficiency', 'Written'],
#  ['MS Office',
#   'MS Excel',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Search Engine Optimization',
#   'SEO',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['English Proficiency', 'Written'],
#  ['MS Office',
#   'MS Word',
#   'MS PowerPoint',
#   'MS Excel',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe After Effects'],
#  ['MS Office',
#   'MS Word',
#   'MS PowerPoint',
#   'Search Engine Optimization',
#   'SEO',
#   'MS Excel'],
#  ['Java', 'Python', 'Data Structures'],
#  ['Blogging', 'Copywriting'],
#  ['MS Office'],
#  ['MS Excel'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Video Editing'],
#  ['MS Office',
#   'Adobe Photoshop',
#   'Magento',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe XD'],
#  ['Salesforce'],
#  ['PHP',
#   'HTML',
#   'CSS',
#   'Adobe Dreamweaver',
#   'Search Engine Optimization',
#   'SEO'],
#  ['English Proficiency',
#   'Spoken',
#   'Hindi Proficiency',
#   'Spoken',
#   'Telugu Proficiency',
#   'Spoken'],
#  ['English Proficiency', 'Written'],
#  ['MS Office',
#   'MS Excel',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Search Engine Optimization',
#   'SEO',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['English Proficiency', 'Written'],
#  ['MS Office',
#   'MS Word',
#   'MS PowerPoint',
#   'MS Excel',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe After Effects'],
#  ['MS Office',
#   'MS Word',
#   'MS PowerPoint',
#   'Search Engine Optimization',
#   'SEO',
#   'MS Excel'],
#  ['Java', 'Python', 'Data Structures'],
#  ['Blogging', 'Copywriting'],
#  ['MS Office'],
#  ['MS Excel'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Video Editing'],
#  ['MS Office',
#   'Adobe Photoshop',
#   'Magento',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe XD'],
#  ['Salesforce'],
#  ['PHP',
#   'HTML',
#   'CSS',
#   'Adobe Dreamweaver',
#   'Search Engine Optimization',
#   'SEO'],
#  ['English Proficiency',
#   'Spoken',
#   'Hindi Proficiency',
#   'Spoken',
#   'Telugu Proficiency',
#   'Spoken'],
#  ['English Proficiency', 'Written'],
#  ['MS Office',
#   'MS Excel',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Search Engine Optimization',
#   'SEO',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['English Proficiency', 'Written'],
#  ['MS Office',
#   'MS Word',
#   'MS PowerPoint',
#   'MS Excel',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe After Effects'],
#  ['MS Office',
#   'MS Word',
#   'MS PowerPoint',
#   'Search Engine Optimization',
#   'SEO',
#   'MS Excel'],
#  ['Java', 'Python', 'Data Structures'],
#  ['Blogging', 'Copywriting'],
#  ['MS Office'],
#  ['MS Excel'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Video Editing'],
#  ['MS Office',
#   'Adobe Photoshop',
#   'Magento',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe XD'],
#  ['Salesforce'],
#  ['PHP',
#   'HTML',
#   'CSS',
#   'Adobe Dreamweaver',
#   'Search Engine Optimization',
#   'SEO'],
#  ['English Proficiency',
#   'Spoken',
#   'Hindi Proficiency',
#   'Spoken',
#   'Telugu Proficiency',
#   'Spoken'],
#  ['English Proficiency', 'Written'],
#  ['MS Office',
#   'MS Excel',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Search Engine Optimization',
#   'SEO',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['English Proficiency', 'Written'],
#  ['MS Office',
#   'MS Word',
#   'MS PowerPoint',
#   'MS Excel',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe After Effects'],
#  ['MS Office',
#   'MS Word',
#   'MS PowerPoint',
#   'Search Engine Optimization',
#   'SEO',
#   'MS Excel'],
#  ['Java', 'Python', 'Data Structures'],
#  ['Blogging', 'Copywriting'],
#  ['MS Office'],
#  ['MS Excel'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Video Editing'],
#  ['MS Office',
#   'Adobe Photoshop',
#   'Magento',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe XD'],
#  ['Salesforce'],
#  ['PHP',
#   'HTML',
#   'CSS',
#   'Adobe Dreamweaver',
#   'Search Engine Optimization',
#   'SEO'],
#  ['English Proficiency',
#   'Spoken',
#   'Hindi Proficiency',
#   'Spoken',
#   'Telugu Proficiency',
#   'Spoken'],
#  ['English Proficiency', 'Written'],
#  ['MS Office',
#   'MS Excel',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Search Engine Optimization',
#   'SEO',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['English Proficiency', 'Written'],
#  ['MS Office',
#   'MS Word',
#   'MS PowerPoint',
#   'MS Excel',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe After Effects'],
#  ['MS Office',
#   'MS Word',
#   'MS PowerPoint',
#   'Search Engine Optimization',
#   'SEO',
#   'MS Excel'],
#  ['Java', 'Python', 'Data Structures'],
#  ['Blogging', 'Copywriting'],
#  ['MS Office'],
#  ['MS Excel'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Video Editing'],
#  ['MS Office',
#   'Adobe Photoshop',
#   'Magento',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe XD'],
#  ['Salesforce'],
#  ['PHP',
#   'HTML',
#   'CSS',
#   'Adobe Dreamweaver',
#   'Search Engine Optimization',
#   'SEO'],
#  ['English Proficiency',
#   'Spoken',
#   'Hindi Proficiency',
#   'Spoken',
#   'Telugu Proficiency',
#   'Spoken'],
#  ['English Proficiency', 'Written'],
#  ['MS Office',
#   'MS Excel',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Search Engine Optimization',
#   'SEO',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['English Proficiency', 'Written'],
#  ['MS Office',
#   'MS Word',
#   'MS PowerPoint',
#   'MS Excel',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe After Effects'],
#  ['MS Office',
#   'MS Word',
#   'MS PowerPoint',
#   'Search Engine Optimization',
#   'SEO',
#   'MS Excel'],
#  ['Java', 'Python', 'Data Structures'],
#  ['Blogging', 'Copywriting'],
#  ['MS Office'],
#  ['MS Excel'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Video Editing'],
#  ['MS Office',
#   'Adobe Photoshop',
#   'Magento',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe XD'],
#  ['Salesforce'],
#  ['PHP',
#   'HTML',
#   'CSS',
#   'Adobe Dreamweaver',
#   'Search Engine Optimization',
#   'SEO'],
#  ['English Proficiency',
#   'Spoken',
#   'Hindi Proficiency',
#   'Spoken',
#   'Telugu Proficiency',
#   'Spoken'],
#  ['English Proficiency', 'Written'],
#  ['MS Office',
#   'MS Excel',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Search Engine Optimization',
#   'SEO',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['English Proficiency', 'Written'],
#  ['MS Office',
#   'MS Word',
#   'MS PowerPoint',
#   'MS Excel',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe After Effects'],
#  ['MS Office',
#   'MS Word',
#   'MS PowerPoint',
#   'Search Engine Optimization',
#   'SEO',
#   'MS Excel'],
#  ['Java', 'Python', 'Data Structures'],
#  ['Blogging', 'Copywriting'],
#  ['MS Office'],
#  ['MS Excel'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Video Editing'],
#  ['MS Office',
#   'Adobe Photoshop',
#   'Magento',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe XD'],
#  ['Salesforce'],
#  ['PHP',
#   'HTML',
#   'CSS',
#   'Adobe Dreamweaver',
#   'Search Engine Optimization',
#   'SEO'],
#  ['English Proficiency',
#   'Spoken',
#   'Hindi Proficiency',
#   'Spoken',
#   'Telugu Proficiency',
#   'Spoken'],
#  ['English Proficiency', 'Written'],
#  ['MS Office',
#   'MS Excel',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Search Engine Optimization',
#   'SEO',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['English Proficiency', 'Written'],
#  ['MS Office',
#   'MS Word',
#   'MS PowerPoint',
#   'MS Excel',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe After Effects'],
#  ['MS Office',
#   'MS Word',
#   'MS PowerPoint',
#   'Search Engine Optimization',
#   'SEO',
#   'MS Excel'],
#  ['Java', 'Python', 'Data Structures'],
#  ['Blogging', 'Copywriting'],
#  ['MS Office'],
#  ['MS Excel'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Video Editing'],
#  ['MS Office',
#   'Adobe Photoshop',
#   'Magento',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe XD'],
#  ['Salesforce'],
#  ['PHP',
#   'HTML',
#   'CSS',
#   'Adobe Dreamweaver',
#   'Search Engine Optimization',
#   'SEO'],
#  ['English Proficiency',
#   'Spoken',
#   'Hindi Proficiency',
#   'Spoken',
#   'Telugu Proficiency',
#   'Spoken'],
#  ['English Proficiency', 'Written'],
#  ['MS Office',
#   'MS Excel',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Search Engine Optimization',
#   'SEO',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['English Proficiency', 'Written'],
#  ['MS Office',
#   'MS Word',
#   'MS PowerPoint',
#   'MS Excel',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe After Effects'],
#  ['MS Office',
#   'MS Word',
#   'MS PowerPoint',
#   'Search Engine Optimization',
#   'SEO',
#   'MS Excel'],
#  ['Java', 'Python', 'Data Structures'],
#  ['Blogging', 'Copywriting'],
#  ['MS Office'],
#  ['MS Excel'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Video Editing'],
#  ['MS Office',
#   'Adobe Photoshop',
#   'Magento',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe XD'],
#  ['Salesforce'],
#  ['PHP',
#   'HTML',
#   'CSS',
#   'Adobe Dreamweaver',
#   'Search Engine Optimization',
#   'SEO'],
#  ['English Proficiency',
#   'Spoken',
#   'Hindi Proficiency',
#   'Spoken',
#   'Telugu Proficiency',
#   'Spoken'],
#  ['English Proficiency', 'Written'],
#  ['MS Office',
#   'MS Excel',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Search Engine Optimization',
#   'SEO',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['English Proficiency', 'Written'],
#  ['MS Office',
#   'MS Word',
#   'MS PowerPoint',
#   'MS Excel',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe After Effects'],
#  ['MS Office',
#   'MS Word',
#   'MS PowerPoint',
#   'Search Engine Optimization',
#   'SEO',
#   'MS Excel'],
#  ['Java', 'Python', 'Data Structures'],
#  ['Blogging', 'Copywriting'],
#  ['MS Office'],
#  ['MS Excel'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Video Editing'],
#  ['MS Office',
#   'Adobe Photoshop',
#   'Magento',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe XD'],
#  ['Salesforce'],
#  ['PHP',
#   'HTML',
#   'CSS',
#   'Adobe Dreamweaver',
#   'Search Engine Optimization',
#   'SEO'],
#  ['English Proficiency',
#   'Spoken',
#   'Hindi Proficiency',
#   'Spoken',
#   'Telugu Proficiency',
#   'Spoken'],
#  ['English Proficiency', 'Written'],
#  ['MS Office',
#   'MS Excel',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Search Engine Optimization',
#   'SEO',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['English Proficiency', 'Written'],
#  ['MS Office',
#   'MS Word',
#   'MS PowerPoint',
#   'MS Excel',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe After Effects'],
#  ['MS Office',
#   'MS Word',
#   'MS PowerPoint',
#   'Search Engine Optimization',
#   'SEO',
#   'MS Excel'],
#  ['Java', 'Python', 'Data Structures'],
#  ['Blogging', 'Copywriting'],
#  ['MS Office'],
#  ['MS Excel'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Video Editing'],
#  ['MS Office',
#   'Adobe Photoshop',
#   'Magento',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe XD'],
#  ['Salesforce'],
#  ['PHP',
#   'HTML',
#   'CSS',
#   'Adobe Dreamweaver',
#   'Search Engine Optimization',
#   'SEO'],
#  ['English Proficiency',
#   'Spoken',
#   'Hindi Proficiency',
#   'Spoken',
#   'Telugu Proficiency',
#   'Spoken'],
#  ['English Proficiency', 'Written'],
#  ['MS Office',
#   'MS Excel',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Search Engine Optimization',
#   'SEO',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['English Proficiency', 'Written'],
#  ['MS Office',
#   'MS Word',
#   'MS PowerPoint',
#   'MS Excel',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe After Effects'],
#  ['MS Office',
#   'MS Word',
#   'MS PowerPoint',
#   'Search Engine Optimization',
#   'SEO',
#   'MS Excel'],
#  ['Java', 'Python', 'Data Structures'],
#  ['Blogging', 'Copywriting'],
#  ['MS Office'],
#  ['MS Excel'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Video Editing'],
#  ['MS Office',
#   'Adobe Photoshop',
#   'Magento',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe XD'],
#  ['Salesforce'],
#  ['PHP',
#   'HTML',
#   'CSS',
#   'Adobe Dreamweaver',
#   'Search Engine Optimization',
#   'SEO'],
#  ['English Proficiency',
#   'Spoken',
#   'Hindi Proficiency',
#   'Spoken',
#   'Telugu Proficiency',
#   'Spoken'],
#  ['English Proficiency', 'Written'],
#  ['MS Office',
#   'MS Excel',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Search Engine Optimization',
#   'SEO',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['English Proficiency', 'Written'],
#  ['MS Office',
#   'MS Word',
#   'MS PowerPoint',
#   'MS Excel',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe After Effects'],
#  ['MS Office',
#   'MS Word',
#   'MS PowerPoint',
#   'Search Engine Optimization',
#   'SEO',
#   'MS Excel'],
#  ['Java', 'Python', 'Data Structures'],
#  ['Blogging', 'Copywriting'],
#  ['MS Office'],
#  ['MS Excel'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Video Editing'],
#  ['MS Office',
#   'Adobe Photoshop',
#   'Magento',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe XD'],
#  ['Salesforce'],
#  ['PHP',
#   'HTML',
#   'CSS',
#   'Adobe Dreamweaver',
#   'Search Engine Optimization',
#   'SEO'],
#  ['English Proficiency',
#   'Spoken',
#   'Hindi Proficiency',
#   'Spoken',
#   'Telugu Proficiency',
#   'Spoken'],
#  ['English Proficiency', 'Written'],
#  ['MS Office',
#   'MS Excel',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Search Engine Optimization',
#   'SEO',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['English Proficiency', 'Written'],
#  ['MS Office',
#   'MS Word',
#   'MS PowerPoint',
#   'MS Excel',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe After Effects'],
#  ['MS Office',
#   'MS Word',
#   'MS PowerPoint',
#   'Search Engine Optimization',
#   'SEO',
#   'MS Excel'],
#  ['Java', 'Python', 'Data Structures'],
#  ['Blogging', 'Copywriting'],
#  ['MS Office'],
#  ['MS Excel'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Video Editing'],
#  ['MS Office',
#   'Adobe Photoshop',
#   'Magento',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe XD'],
#  ['Salesforce'],
#  ['PHP',
#   'HTML',
#   'CSS',
#   'Adobe Dreamweaver',
#   'Search Engine Optimization',
#   'SEO'],
#  ['English Proficiency',
#   'Spoken',
#   'Hindi Proficiency',
#   'Spoken',
#   'Telugu Proficiency',
#   'Spoken'],
#  ['English Proficiency', 'Written'],
#  ['MS Office',
#   'MS Excel',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Search Engine Optimization',
#   'SEO',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['English Proficiency', 'Written'],
#  ['MS Office',
#   'MS Word',
#   'MS PowerPoint',
#   'MS Excel',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe After Effects'],
#  ['MS Office',
#   'MS Word',
#   'MS PowerPoint',
#   'Search Engine Optimization',
#   'SEO',
#   'MS Excel'],
#  ['Java', 'Python', 'Data Structures'],
#  ['Blogging', 'Copywriting'],
#  ['MS Office'],
#  ['MS Excel'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Video Editing'],
#  ['MS Office',
#   'Adobe Photoshop',
#   'Magento',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe XD'],
#  ['Salesforce'],
#  ['PHP',
#   'HTML',
#   'CSS',
#   'Adobe Dreamweaver',
#   'Search Engine Optimization',
#   'SEO'],
#  ['English Proficiency',
#   'Spoken',
#   'Hindi Proficiency',
#   'Spoken',
#   'Telugu Proficiency',
#   'Spoken'],
#  ['English Proficiency', 'Written'],
#  ['MS Office',
#   'MS Excel',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Search Engine Optimization',
#   'SEO',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['English Proficiency', 'Written'],
#  ['MS Office',
#   'MS Word',
#   'MS PowerPoint',
#   'MS Excel',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe After Effects'],
#  ['MS Office',
#   'MS Word',
#   'MS PowerPoint',
#   'Search Engine Optimization',
#   'SEO',
#   'MS Excel'],
#  ['Java', 'Python', 'Data Structures'],
#  ['Blogging', 'Copywriting'],
#  ['MS Office'],
#  ['MS Excel'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Video Editing'],
#  ['MS Office',
#   'Adobe Photoshop',
#   'Magento',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe XD'],
#  ['Salesforce'],
#  ['PHP',
#   'HTML',
#   'CSS',
#   'Adobe Dreamweaver',
#   'Search Engine Optimization',
#   'SEO'],
#  ['English Proficiency',
#   'Spoken',
#   'Hindi Proficiency',
#   'Spoken',
#   'Telugu Proficiency',
#   'Spoken'],
#  ['English Proficiency', 'Written'],
#  ['MS Office',
#   'MS Excel',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Search Engine Optimization',
#   'SEO',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['English Proficiency', 'Written'],
#  ['MS Office',
#   'MS Word',
#   'MS PowerPoint',
#   'MS Excel',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe After Effects'],
#  ['MS Office',
#   'MS Word',
#   'MS PowerPoint',
#   'Search Engine Optimization',
#   'SEO',
#   'MS Excel'],
#  ['Java', 'Python', 'Data Structures'],
#  ['Blogging', 'Copywriting'],
#  ['MS Office'],
#  ['MS Excel'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Video Editing'],
#  ['MS Office',
#   'Adobe Photoshop',
#   'Magento',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe XD'],
#  ['Salesforce'],
#  ['PHP',
#   'HTML',
#   'CSS',
#   'Adobe Dreamweaver',
#   'Search Engine Optimization',
#   'SEO'],
#  ['English Proficiency',
#   'Spoken',
#   'Hindi Proficiency',
#   'Spoken',
#   'Telugu Proficiency',
#   'Spoken'],
#  ['English Proficiency', 'Written'],
#  ['MS Office',
#   'MS Excel',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Search Engine Optimization',
#   'SEO',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['English Proficiency', 'Written'],
#  ['MS Office',
#   'MS Word',
#   'MS PowerPoint',
#   'MS Excel',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe After Effects'],
#  ['MS Office',
#   'MS Word',
#   'MS PowerPoint',
#   'Search Engine Optimization',
#   'SEO',
#   'MS Excel'],
#  ['Java', 'Python', 'Data Structures'],
#  ['Blogging', 'Copywriting'],
#  ['MS Office'],
#  ['MS Excel'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Video Editing'],
#  ['MS Office',
#   'Adobe Photoshop',
#   'Magento',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe XD'],
#  ['Salesforce'],
#  ['PHP',
#   'HTML',
#   'CSS',
#   'Adobe Dreamweaver',
#   'Search Engine Optimization',
#   'SEO'],
#  ['English Proficiency',
#   'Spoken',
#   'Hindi Proficiency',
#   'Spoken',
#   'Telugu Proficiency',
#   'Spoken'],
#  ['English Proficiency', 'Written'],
#  ['MS Office',
#   'MS Excel',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Search Engine Optimization',
#   'SEO',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['English Proficiency', 'Written'],
#  ['MS Office',
#   'MS Word',
#   'MS PowerPoint',
#   'MS Excel',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe After Effects'],
#  ['MS Office',
#   'MS Word',
#   'MS PowerPoint',
#   'Search Engine Optimization',
#   'SEO',
#   'MS Excel'],
#  ['Java', 'Python', 'Data Structures'],
#  ['Blogging', 'Copywriting'],
#  ['MS Office'],
#  ['MS Excel'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Video Editing'],
#  ['MS Office',
#   'Adobe Photoshop',
#   'Magento',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe XD'],
#  ['Salesforce'],
#  ['PHP',
#   'HTML',
#   'CSS',
#   'Adobe Dreamweaver',
#   'Search Engine Optimization',
#   'SEO'],
#  ['English Proficiency',
#   'Spoken',
#   'Hindi Proficiency',
#   'Spoken',
#   'Telugu Proficiency',
#   'Spoken'],
#  ['English Proficiency', 'Written'],
#  ['MS Office',
#   'MS Excel',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Search Engine Optimization',
#   'SEO',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['English Proficiency', 'Written'],
#  ['MS Office',
#   'MS Word',
#   'MS PowerPoint',
#   'MS Excel',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe After Effects'],
#  ['MS Office',
#   'MS Word',
#   'MS PowerPoint',
#   'Search Engine Optimization',
#   'SEO',
#   'MS Excel'],
#  ['Java', 'Python', 'Data Structures'],
#  ['Blogging', 'Copywriting'],
#  ['MS Office'],
#  ['MS Excel'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Video Editing'],
#  ['MS Office',
#   'Adobe Photoshop',
#   'Magento',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe XD'],
#  ['Salesforce'],
#  ['PHP',
#   'HTML',
#   'CSS',
#   'Adobe Dreamweaver',
#   'Search Engine Optimization',
#   'SEO'],
#  ['English Proficiency',
#   'Spoken',
#   'Hindi Proficiency',
#   'Spoken',
#   'Telugu Proficiency',
#   'Spoken'],
#  ['English Proficiency', 'Written'],
#  ['MS Office',
#   'MS Excel',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Search Engine Optimization',
#   'SEO',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['English Proficiency', 'Written'],
#  ['MS Office',
#   'MS Word',
#   'MS PowerPoint',
#   'MS Excel',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe After Effects'],
#  ['MS Office',
#   'MS Word',
#   'MS PowerPoint',
#   'Search Engine Optimization',
#   'SEO',
#   'MS Excel'],
#  ['Java', 'Python', 'Data Structures'],
#  ['Blogging', 'Copywriting'],
#  ['MS Office'],
#  ['MS Excel'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Video Editing'],
#  ['MS Office',
#   'Adobe Photoshop',
#   'Magento',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe XD'],
#  ['Salesforce'],
#  ['PHP',
#   'HTML',
#   'CSS',
#   'Adobe Dreamweaver',
#   'Search Engine Optimization',
#   'SEO'],
#  ['English Proficiency',
#   'Spoken',
#   'Hindi Proficiency',
#   'Spoken',
#   'Telugu Proficiency',
#   'Spoken'],
#  ['English Proficiency', 'Written'],
#  ['MS Office',
#   'MS Excel',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Search Engine Optimization',
#   'SEO',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['English Proficiency', 'Written'],
#  ['MS Office',
#   'MS Word',
#   'MS PowerPoint',
#   'MS Excel',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe After Effects'],
#  ['MS Office',
#   'MS Word',
#   'MS PowerPoint',
#   'Search Engine Optimization',
#   'SEO',
#   'MS Excel'],
#  ['Java', 'Python', 'Data Structures'],
#  ['Blogging', 'Copywriting'],
#  ['MS Office'],
#  ['MS Excel'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Video Editing'],
#  ['MS Office',
#   'Adobe Photoshop',
#   'Magento',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe XD'],
#  ['Salesforce'],
#  ['PHP',
#   'HTML',
#   'CSS',
#   'Adobe Dreamweaver',
#   'Search Engine Optimization',
#   'SEO'],
#  ['English Proficiency',
#   'Spoken',
#   'Hindi Proficiency',
#   'Spoken',
#   'Telugu Proficiency',
#   'Spoken'],
#  ['English Proficiency', 'Written'],
#  ['MS Office',
#   'MS Excel',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Search Engine Optimization',
#   'SEO',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['English Proficiency', 'Written'],
#  ['MS Office',
#   'MS Word',
#   'MS PowerPoint',
#   'MS Excel',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe After Effects'],
#  ['MS Office',
#   'MS Word',
#   'MS PowerPoint',
#   'Search Engine Optimization',
#   'SEO',
#   'MS Excel'],
#  ['Java', 'Python', 'Data Structures'],
#  ['Blogging', 'Copywriting'],
#  ['MS Office'],
#  ['MS Excel'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Video Editing'],
#  ['MS Office',
#   'Adobe Photoshop',
#   'Magento',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe XD'],
#  ['Salesforce'],
#  ['PHP',
#   'HTML',
#   'CSS',
#   'Adobe Dreamweaver',
#   'Search Engine Optimization',
#   'SEO'],
#  ['English Proficiency',
#   'Spoken',
#   'Hindi Proficiency',
#   'Spoken',
#   'Telugu Proficiency',
#   'Spoken'],
#  ['English Proficiency', 'Written'],
#  ['MS Office',
#   'MS Excel',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Search Engine Optimization',
#   'SEO',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['English Proficiency', 'Written'],
#  ['MS Office',
#   'MS Word',
#   'MS PowerPoint',
#   'MS Excel',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe After Effects'],
#  ['MS Office',
#   'MS Word',
#   'MS PowerPoint',
#   'Search Engine Optimization',
#   'SEO',
#   'MS Excel'],
#  ['Java', 'Python', 'Data Structures'],
#  ['Blogging', 'Copywriting'],
#  ['MS Office'],
#  ['MS Excel'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Video Editing'],
#  ['MS Office',
#   'Adobe Photoshop',
#   'Magento',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe XD'],
#  ['Salesforce'],
# ...
#   'SEO',
#   'MS Excel'],
#  ['Java', 'Python', 'Data Structures'],
#  ['Blogging', 'Copywriting'],
#  ['MS Office'],
#  ['MS Excel'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Video Editing'],
#  ['MS Office',
#   'Adobe Photoshop',
#   'Magento',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe XD'],
#  ['Salesforce'],
#  ['PHP',
#   'HTML',
#   'CSS',
#   'Adobe Dreamweaver',
#   'Search Engine Optimization',
#   'SEO'],
#  ['English Proficiency',
#   'Spoken',
#   'Hindi Proficiency',
#   'Spoken',
#   'Telugu Proficiency',
#   'Spoken'],
#  ['English Proficiency', 'Written'],
#  ['MS Office',
#   'MS Excel',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Search Engine Optimization',
#   'SEO',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['English Proficiency', 'Written'],
#  ['MS Office',
#   'MS Word',
#   'MS PowerPoint',
#   'MS Excel',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe After Effects'],
#  ['MS Office',
#   'MS Word',
#   'MS PowerPoint',
#   'Search Engine Optimization',
#   'SEO',
#   'MS Excel'],
#  ['Java', 'Python', 'Data Structures'],
#  ['Blogging', 'Copywriting'],
#  ['MS Office'],
#  ['MS Excel'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Video Editing'],
#  ['MS Office',
#   'Adobe Photoshop',
#   'Magento',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe XD'],
#  ['Salesforce'],
#  ['PHP',
#   'HTML',
#   'CSS',
#   'Adobe Dreamweaver',
#   'Search Engine Optimization',
#   'SEO'],
#  ['English Proficiency',
#   'Spoken',
#   'Hindi Proficiency',
#   'Spoken',
#   'Telugu Proficiency',
#   'Spoken'],
#  ['English Proficiency', 'Written'],
#  ['MS Office',
#   'MS Excel',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Search Engine Optimization',
#   'SEO',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['English Proficiency', 'Written'],
#  ['MS Office',
#   'MS Word',
#   'MS PowerPoint',
#   'MS Excel',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe After Effects'],
#  ['MS Office',
#   'MS Word',
#   'MS PowerPoint',
#   'Search Engine Optimization',
#   'SEO',
#   'MS Excel'],
#  ['Java', 'Python', 'Data Structures'],
#  ['Blogging', 'Copywriting'],
#  ['MS Office'],
#  ['MS Excel'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Video Editing'],
#  ['MS Office',
#   'Adobe Photoshop',
#   'Magento',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe XD'],
#  ['Salesforce'],
#  ['PHP',
#   'HTML',
#   'CSS',
#   'Adobe Dreamweaver',
#   'Search Engine Optimization',
#   'SEO'],
#  ['English Proficiency',
#   'Spoken',
#   'Hindi Proficiency',
#   'Spoken',
#   'Telugu Proficiency',
#   'Spoken'],
#  ['English Proficiency', 'Written'],
#  ['MS Office',
#   'MS Excel',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Search Engine Optimization',
#   'SEO',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['English Proficiency', 'Written'],
#  ['MS Office',
#   'MS Word',
#   'MS PowerPoint',
#   'MS Excel',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe After Effects'],
#  ['MS Office',
#   'MS Word',
#   'MS PowerPoint',
#   'Search Engine Optimization',
#   'SEO',
#   'MS Excel'],
#  ['Java', 'Python', 'Data Structures'],
#  ['Blogging', 'Copywriting'],
#  ['MS Office'],
#  ['MS Excel'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Video Editing'],
#  ['MS Office',
#   'Adobe Photoshop',
#   'Magento',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe XD'],
#  ['Salesforce'],
#  ['PHP',
#   'HTML',
#   'CSS',
#   'Adobe Dreamweaver',
#   'Search Engine Optimization',
#   'SEO'],
#  ['English Proficiency',
#   'Spoken',
#   'Hindi Proficiency',
#   'Spoken',
#   'Telugu Proficiency',
#   'Spoken'],
#  ['English Proficiency', 'Written'],
#  ['MS Office',
#   'MS Excel',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Search Engine Optimization',
#   'SEO',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['English Proficiency', 'Written'],
#  ['MS Office',
#   'MS Word',
#   'MS PowerPoint',
#   'MS Excel',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe After Effects'],
#  ['MS Office',
#   'MS Word',
#   'MS PowerPoint',
#   'Search Engine Optimization',
#   'SEO',
#   'MS Excel'],
#  ['Java', 'Python', 'Data Structures'],
#  ['Blogging', 'Copywriting'],
#  ['MS Office'],
#  ['MS Excel'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Video Editing'],
#  ['MS Office',
#   'Adobe Photoshop',
#   'Magento',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe XD'],
#  ['Salesforce'],
#  ['PHP',
#   'HTML',
#   'CSS',
#   'Adobe Dreamweaver',
#   'Search Engine Optimization',
#   'SEO'],
#  ['English Proficiency',
#   'Spoken',
#   'Hindi Proficiency',
#   'Spoken',
#   'Telugu Proficiency',
#   'Spoken'],
#  ['English Proficiency', 'Written'],
#  ['MS Office',
#   'MS Excel',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Search Engine Optimization',
#   'SEO',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['English Proficiency', 'Written'],
#  ['MS Office',
#   'MS Word',
#   'MS PowerPoint',
#   'MS Excel',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe After Effects'],
#  ['MS Office',
#   'MS Word',
#   'MS PowerPoint',
#   'Search Engine Optimization',
#   'SEO',
#   'MS Excel'],
#  ['Java', 'Python', 'Data Structures'],
#  ['Blogging', 'Copywriting'],
#  ['MS Office'],
#  ['MS Excel'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Video Editing'],
#  ['MS Office',
#   'Adobe Photoshop',
#   'Magento',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe XD'],
#  ['Salesforce'],
#  ['PHP',
#   'HTML',
#   'CSS',
#   'Adobe Dreamweaver',
#   'Search Engine Optimization',
#   'SEO'],
#  ['English Proficiency',
#   'Spoken',
#   'Hindi Proficiency',
#   'Spoken',
#   'Telugu Proficiency',
#   'Spoken'],
#  ['English Proficiency', 'Written'],
#  ['MS Office',
#   'MS Excel',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Search Engine Optimization',
#   'SEO',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['English Proficiency', 'Written'],
#  ['MS Office',
#   'MS Word',
#   'MS PowerPoint',
#   'MS Excel',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe After Effects'],
#  ['MS Office',
#   'MS Word',
#   'MS PowerPoint',
#   'Search Engine Optimization',
#   'SEO',
#   'MS Excel'],
#  ['Java', 'Python', 'Data Structures'],
#  ['Blogging', 'Copywriting'],
#  ['MS Office'],
#  ['MS Excel'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Video Editing'],
#  ['MS Office',
#   'Adobe Photoshop',
#   'Magento',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe XD'],
#  ['Salesforce'],
#  ['PHP',
#   'HTML',
#   'CSS',
#   'Adobe Dreamweaver',
#   'Search Engine Optimization',
#   'SEO'],
#  ['English Proficiency',
#   'Spoken',
#   'Hindi Proficiency',
#   'Spoken',
#   'Telugu Proficiency',
#   'Spoken'],
#  ['English Proficiency', 'Written'],
#  ['MS Office',
#   'MS Excel',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Search Engine Optimization',
#   'SEO',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['English Proficiency', 'Written'],
#  ['MS Office',
#   'MS Word',
#   'MS PowerPoint',
#   'MS Excel',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe After Effects'],
#  ['MS Office',
#   'MS Word',
#   'MS PowerPoint',
#   'Search Engine Optimization',
#   'SEO',
#   'MS Excel'],
#  ['Java', 'Python', 'Data Structures'],
#  ['Blogging', 'Copywriting'],
#  ['MS Office'],
#  ['MS Excel'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Video Editing'],
#  ['MS Office',
#   'Adobe Photoshop',
#   'Magento',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe XD'],
#  ['Salesforce'],
#  ['PHP',
#   'HTML',
#   'CSS',
#   'Adobe Dreamweaver',
#   'Search Engine Optimization',
#   'SEO'],
#  ['English Proficiency',
#   'Spoken',
#   'Hindi Proficiency',
#   'Spoken',
#   'Telugu Proficiency',
#   'Spoken'],
#  ['English Proficiency', 'Written'],
#  ['MS Office',
#   'MS Excel',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Search Engine Optimization',
#   'SEO',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['English Proficiency', 'Written'],
#  ['MS Office',
#   'MS Word',
#   'MS PowerPoint',
#   'MS Excel',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe After Effects'],
#  ['MS Office',
#   'MS Word',
#   'MS PowerPoint',
#   'Search Engine Optimization',
#   'SEO',
#   'MS Excel'],
#  ['Java', 'Python', 'Data Structures'],
#  ['Blogging', 'Copywriting'],
#  ['MS Office'],
#  ['MS Excel'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Video Editing'],
#  ['MS Office',
#   'Adobe Photoshop',
#   'Magento',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe XD'],
#  ['Salesforce'],
#  ['PHP',
#   'HTML',
#   'CSS',
#   'Adobe Dreamweaver',
#   'Search Engine Optimization',
#   'SEO'],
#  ['English Proficiency',
#   'Spoken',
#   'Hindi Proficiency',
#   'Spoken',
#   'Telugu Proficiency',
#   'Spoken'],
#  ['English Proficiency', 'Written'],
#  ['MS Office',
#   'MS Excel',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Search Engine Optimization',
#   'SEO',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['English Proficiency', 'Written'],
#  ['MS Office',
#   'MS Word',
#   'MS PowerPoint',
#   'MS Excel',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe After Effects'],
#  ['MS Office',
#   'MS Word',
#   'MS PowerPoint',
#   'Search Engine Optimization',
#   'SEO',
#   'MS Excel'],
#  ['Java', 'Python', 'Data Structures'],
#  ['Blogging', 'Copywriting'],
#  ['MS Office'],
#  ['MS Excel'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Video Editing'],
#  ['MS Office',
#   'Adobe Photoshop',
#   'Magento',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe XD'],
#  ['Salesforce'],
#  ['PHP',
#   'HTML',
#   'CSS',
#   'Adobe Dreamweaver',
#   'Search Engine Optimization',
#   'SEO'],
#  ['English Proficiency',
#   'Spoken',
#   'Hindi Proficiency',
#   'Spoken',
#   'Telugu Proficiency',
#   'Spoken'],
#  ['English Proficiency', 'Written'],
#  ['MS Office',
#   'MS Excel',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Search Engine Optimization',
#   'SEO',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['English Proficiency', 'Written'],
#  ['MS Office',
#   'MS Word',
#   'MS PowerPoint',
#   'MS Excel',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe After Effects'],
#  ['MS Office',
#   'MS Word',
#   'MS PowerPoint',
#   'Search Engine Optimization',
#   'SEO',
#   'MS Excel'],
#  ['Java', 'Python', 'Data Structures'],
#  ['Blogging', 'Copywriting'],
#  ['MS Office'],
#  ['MS Excel'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Video Editing'],
#  ['MS Office',
#   'Adobe Photoshop',
#   'Magento',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe XD'],
#  ['Salesforce'],
#  ['PHP',
#   'HTML',
#   'CSS',
#   'Adobe Dreamweaver',
#   'Search Engine Optimization',
#   'SEO'],
#  ['English Proficiency',
#   'Spoken',
#   'Hindi Proficiency',
#   'Spoken',
#   'Telugu Proficiency',
#   'Spoken'],
#  ['English Proficiency', 'Written'],
#  ['MS Office',
#   'MS Excel',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Search Engine Optimization',
#   'SEO',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['English Proficiency', 'Written'],
#  ['MS Office',
#   'MS Word',
#   'MS PowerPoint',
#   'MS Excel',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe After Effects'],
#  ['MS Office',
#   'MS Word',
#   'MS PowerPoint',
#   'Search Engine Optimization',
#   'SEO',
#   'MS Excel'],
#  ['Java', 'Python', 'Data Structures'],
#  ['Blogging', 'Copywriting'],
#  ['MS Office'],
#  ['MS Excel'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Video Editing'],
#  ['MS Office',
#   'Adobe Photoshop',
#   'Magento',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe XD'],
#  ['Salesforce'],
#  ['PHP',
#   'HTML',
#   'CSS',
#   'Adobe Dreamweaver',
#   'Search Engine Optimization',
#   'SEO'],
#  ['English Proficiency',
#   'Spoken',
#   'Hindi Proficiency',
#   'Spoken',
#   'Telugu Proficiency',
#   'Spoken'],
#  ['English Proficiency', 'Written'],
#  ['MS Office',
#   'MS Excel',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Search Engine Optimization',
#   'SEO',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['English Proficiency', 'Written'],
#  ['MS Office',
#   'MS Word',
#   'MS PowerPoint',
#   'MS Excel',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe After Effects'],
#  ['MS Office',
#   'MS Word',
#   'MS PowerPoint',
#   'Search Engine Optimization',
#   'SEO',
#   'MS Excel'],
#  ['Java', 'Python', 'Data Structures'],
#  ['Blogging', 'Copywriting'],
#  ['MS Office'],
#  ['MS Excel'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Video Editing'],
#  ['MS Office',
#   'Adobe Photoshop',
#   'Magento',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe XD'],
#  ['Salesforce'],
#  ['PHP',
#   'HTML',
#   'CSS',
#   'Adobe Dreamweaver',
#   'Search Engine Optimization',
#   'SEO'],
#  ['English Proficiency',
#   'Spoken',
#   'Hindi Proficiency',
#   'Spoken',
#   'Telugu Proficiency',
#   'Spoken'],
#  ['English Proficiency', 'Written'],
#  ['MS Office',
#   'MS Excel',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Search Engine Optimization',
#   'SEO',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['English Proficiency', 'Written'],
#  ['MS Office',
#   'MS Word',
#   'MS PowerPoint',
#   'MS Excel',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe After Effects'],
#  ['MS Office',
#   'MS Word',
#   'MS PowerPoint',
#   'Search Engine Optimization',
#   'SEO',
#   'MS Excel'],
#  ['Java', 'Python', 'Data Structures'],
#  ['Blogging', 'Copywriting'],
#  ['MS Office'],
#  ['MS Excel'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Video Editing'],
#  ['MS Office',
#   'Adobe Photoshop',
#   'Magento',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Adobe Photoshop', 'Adobe Illustrator', 'Adobe XD'],
#  ['Salesforce'],
#  ['PHP',
#   'HTML',
#   'CSS',
#   'Adobe Dreamweaver',
#   'Search Engine Optimization',
#   'SEO'],
#  ['English Proficiency',
#   'Spoken',
#   'Hindi Proficiency',
#   'Spoken',
#   'Telugu Proficiency',
#   'Spoken'],
#  ['English Proficiency', 'Written'],
#  ['MS Office',
#   'MS Excel',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['Search Engine Optimization',
#   'SEO',
#   'English Proficiency',
#   'Spoken',
#   'English Proficiency',
#   'Written'],
#  ['English Proficiency', 'Written'],
#  ...]

# %%
items = [records[i][j] for i in range(len(records)) for j in range(len(records[i]))]

# %%
set(items)
# Out:
# {'AJAX',
#  'ANSYS',
#  'ARM Microcontroller',
#  'ASP NET',
#  'Adobe After Effects',
#  'Adobe Creative Suite',
#  'Adobe Dreamweaver',
#  'Adobe Flash',
#  'Adobe Illustrator',
#  'Adobe Photoshop',
#  'Adobe Premiere Pro',
#  'Adobe XD',
#  'Analog And Digital Circuits',
#  'Android',
#  'Animation',
#  'Arduino',
#  'Artifical Intelligence',
#  'AutoCAD',
#  'Biology',
#  'Blogging',
#  'C',
#  'C Programming',
#  'CSS',
#  'Catalyst MVC Web Framework',
#  'Circuit Design',
#  'Cloud Computing',
#  'CodeIgniter',
#  'Computer Networking',
#  'Computer Vision',
#  'Copywriting',
#  'Creative Writing',
#  'Data Analytics',
#  'Data Science',
#  'Data Structures',
#  'DevOps',
#  'Digital Marketing',
#  'Digital Signal Processing',
#  'Email Marketing',
#  'Embedded Systems',
#  'English Proficiency',
#  'Facebook Marketing',
#  'Figma',
#  'Flutter',
#  'Google AdWords',
#  'Google Analytics',
#  'Google SketchUp',
#  'HTML',
#  'Hindi Proficiency',
#  'Internet of Things',
#  'IoT',
#  'JSON',
#  'Java',
#  'JavaScript',
#  'LARAVEL',
#  'MS Excel',
#  'MS Office',
#  'MS PowerPoint',
#  'MS Word',
#  'Magento',
#  'Mathematics',
#  'Moodle',
#  'MySQL',
#  'NET',
#  'OpenCV',
#  'PHP',
#  'Programming',
#  'Python',
#  'REST API',
#  'Rapid Prototyping',
#  'SEM',
#  'SEO',
#  'SQL',
#  'Salesforce',
#  'Search Engine Marketing',
#  'Search Engine Optimization',
#  'Social Media Marketing',
#  'Spoken',
#  'Telugu Proficiency',
#  'UI',
#  'UX Design',
#  'Video Editing',
#  'Web Application Security',
#  'WordPress',
#  'Written',
#  'iOS'}

# %% [markdown]
# ##### above listed skills are unique items

# %%
minimum_support_count = 25

# %%
def stage_1(items, minimum_support_count):
    c1 = {i:items.count(i) for i in items}
    l1 = {}
    for key, value in c1.items():
        if value >= minimum_support_count:
            l1[key] = value
    return c1, l1
c1, l1 = stage_1(items, minimum_support_count)

# %%
l1
# Out:
# {'Java': 193,
#  'Python': 230,
#  'Data Structures': 181,
#  'Blogging': 181,
#  'Copywriting': 181,
#  'MS Office': 1038,
#  'MS Excel': 849,
#  'Adobe Photoshop': 777,
#  'Adobe Illustrator': 564,
#  'Video Editing': 180,
#  'Magento': 187,
#  'English Proficiency': 2117,
#  'Spoken': 1373,
#  'Written': 1122,
#  'Adobe XD': 181,
#  'Salesforce': 180,
#  'PHP': 247,
#  'HTML': 225,
#  'CSS': 225,
#  'Adobe Dreamweaver': 197,
#  'Search Engine Optimization': 576,
#  'SEO': 576,
#  'Hindi Proficiency': 197,
#  'Telugu Proficiency': 181,
#  'MS Word': 383,
#  'MS PowerPoint': 431,
#  'Adobe After Effects': 187,
#  'Digital Marketing': 40,
#  'Social Media Marketing': 40,
#  'Email Marketing': 38,
#  'OpenCV': 32,
#  'C': 44,
#  'NET': 28,
#  'JavaScript': 50}

# %%
def sublist(lst1, lst2):
    return set(lst1) <= set(lst2)

def check_subset_frequency(itemset, l, n):
    if n>1:    
        subsets = list(itertools.combinations(itemset, n))
    else:
        subsets = itemset
    for iter1 in subsets:
        if not iter1 in l:
            return False
    return True

# %%
def stage_2(l1, records, minimum_support_count):
    l1 = sorted(list(l1.keys()))
    L1 = list(itertools.combinations(l1, 2))
    c2 = {}
    l2 = {}
    for iter1 in L1:
        count = 0
        for iter2 in records:
            if sublist(iter1, iter2):
                count+=1
        c2[iter1] = count
    for key, value in c2.items():
        if value >= minimum_support_count:
            if check_subset_frequency(key, l1, 1):
                l2[key] = value 
    
    return c2, l2
c2, l2 = stage_2(l1, records, minimum_support_count)

# %%
l2
# Out:
# {('Adobe After Effects', 'Adobe Illustrator'): 187,
#  ('Adobe After Effects', 'Adobe Photoshop'): 187,
#  ('Adobe Dreamweaver', 'CSS'): 181,
#  ('Adobe Dreamweaver', 'HTML'): 181,
#  ('Adobe Dreamweaver', 'PHP'): 181,
#  ('Adobe Dreamweaver', 'SEO'): 181,
#  ('Adobe Dreamweaver', 'Search Engine Optimization'): 181,
#  ('Adobe Illustrator', 'Adobe Photoshop'): 564,
#  ('Adobe Illustrator', 'Adobe XD'): 181,
#  ('Adobe Illustrator', 'Video Editing'): 180,
#  ('Adobe Photoshop', 'Adobe XD'): 181,
#  ('Adobe Photoshop', 'English Proficiency'): 181,
#  ('Adobe Photoshop', 'MS Office'): 181,
#  ('Adobe Photoshop', 'Magento'): 181,
#  ('Adobe Photoshop', 'Spoken'): 181,
#  ('Adobe Photoshop', 'Video Editing'): 180,
#  ('Adobe Photoshop', 'Written'): 181,
#  ('Blogging', 'Copywriting'): 181,
#  ('C', 'NET'): 28,
#  ('C', 'Python'): 32,
#  ('CSS', 'HTML'): 225,
#  ('CSS', 'JavaScript'): 38,
#  ('CSS', 'PHP'): 219,
#  ('CSS', 'SEO'): 181,
#  ('CSS', 'Search Engine Optimization'): 181,
#  ('Data Structures', 'Java'): 181,
#  ('Data Structures', 'Python'): 181,
#  ('English Proficiency', 'Hindi Proficiency'): 197,
#  ('English Proficiency', 'MS Excel'): 374,
#  ('English Proficiency', 'MS Office'): 603,
#  ('English Proficiency', 'MS PowerPoint'): 187,
#  ('English Proficiency', 'MS Word'): 187,
#  ('English Proficiency', 'Magento'): 181,
#  ('English Proficiency', 'SEO'): 181,
#  ('English Proficiency', 'Search Engine Optimization'): 181,
#  ('English Proficiency', 'Spoken'): 995,
#  ('English Proficiency', 'Telugu Proficiency'): 181,
#  ('English Proficiency', 'Written'): 1122,
#  ('HTML', 'JavaScript'): 38,
#  ('HTML', 'PHP'): 219,
#  ('HTML', 'SEO'): 181,
#  ('HTML', 'Search Engine Optimization'): 181,
#  ('Hindi Proficiency', 'Spoken'): 197,
#  ('Hindi Proficiency', 'Telugu Proficiency'): 181,
#  ('Java', 'Python'): 181,
#  ('JavaScript', 'PHP'): 44,
#  ('MS Excel', 'MS Office'): 596,
#  ('MS Excel', 'MS PowerPoint'): 415,
#  ('MS Excel', 'MS Word'): 383,
#  ('MS Excel', 'SEO'): 196,
#  ('MS Excel', 'Search Engine Optimization'): 196,
#  ('MS Excel', 'Spoken'): 374,
#  ('MS Excel', 'Written'): 374,
#  ('MS Office', 'MS PowerPoint'): 393,
#  ('MS Office', 'MS Word'): 377,
#  ('MS Office', 'Magento'): 181,
#  ('MS Office', 'SEO'): 180,
#  ('MS Office', 'Search Engine Optimization'): 180,
#  ('MS Office', 'Spoken'): 597,
#  ('MS Office', 'Written'): 555,
#  ('MS PowerPoint', 'MS Word'): 367,
#  ('MS PowerPoint', 'SEO'): 180,
#  ('MS PowerPoint', 'Search Engine Optimization'): 180,
#  ('MS PowerPoint', 'Spoken'): 187,
#  ('MS PowerPoint', 'Written'): 187,
#  ('MS Word', 'SEO'): 180,
#  ('MS Word', 'Search Engine Optimization'): 180,
#  ('MS Word', 'Spoken'): 187,
#  ('MS Word', 'Written'): 187,
#  ('Magento', 'Spoken'): 181,
#  ('Magento', 'Written'): 181,
#  ('PHP', 'SEO'): 181,
#  ('PHP', 'Search Engine Optimization'): 181,
#  ('SEO', 'Search Engine Optimization'): 576,
#  ('SEO', 'Spoken'): 181,
#  ('SEO', 'Written'): 181,
#  ('Search Engine Optimization', 'Spoken'): 181,
#  ('Search Engine Optimization', 'Written'): 181,
#  ('Spoken', 'Telugu Proficiency'): 181,
#  ('Spoken', 'Written'): 754}

# %%
def stage_3(l2, records, minimum_support_count):
    l2 = list(l2.keys())
    L2 = sorted(list(set([item for t in l2 for item in t])))
    L2 = list(itertools.combinations(L2, 3))
    c3 = {}
    l3 = {}
    for iter1 in L2:
        count = 0
        for iter2 in records:
            if sublist(iter1, iter2):
                count+=1
        c3[iter1] = count
    for key, value in c3.items():
        if value >= minimum_support_count:
            if check_subset_frequency(key, l2, 2):
                l3[key] = value 
        
    return c3, l3
c3, l3 = stage_3(l2, records, minimum_support_count)

# %%
l3
# Out:
# {('Adobe After Effects', 'Adobe Illustrator', 'Adobe Photoshop'): 187,
#  ('Adobe Dreamweaver', 'CSS', 'HTML'): 181,
#  ('Adobe Dreamweaver', 'CSS', 'PHP'): 181,
#  ('Adobe Dreamweaver', 'CSS', 'SEO'): 181,
#  ('Adobe Dreamweaver', 'CSS', 'Search Engine Optimization'): 181,
#  ('Adobe Dreamweaver', 'HTML', 'PHP'): 181,
#  ('Adobe Dreamweaver', 'HTML', 'SEO'): 181,
#  ('Adobe Dreamweaver', 'HTML', 'Search Engine Optimization'): 181,
#  ('Adobe Dreamweaver', 'PHP', 'SEO'): 181,
#  ('Adobe Dreamweaver', 'PHP', 'Search Engine Optimization'): 181,
#  ('Adobe Dreamweaver', 'SEO', 'Search Engine Optimization'): 181,
#  ('Adobe Illustrator', 'Adobe Photoshop', 'Adobe XD'): 181,
#  ('Adobe Illustrator', 'Adobe Photoshop', 'Video Editing'): 180,
#  ('Adobe Photoshop', 'English Proficiency', 'MS Office'): 181,
#  ('Adobe Photoshop', 'English Proficiency', 'Magento'): 181,
#  ('Adobe Photoshop', 'English Proficiency', 'Spoken'): 181,
#  ('Adobe Photoshop', 'English Proficiency', 'Written'): 181,
#  ('Adobe Photoshop', 'MS Office', 'Magento'): 181,
#  ('Adobe Photoshop', 'MS Office', 'Spoken'): 181,
#  ('Adobe Photoshop', 'MS Office', 'Written'): 181,
#  ('Adobe Photoshop', 'Magento', 'Spoken'): 181,
#  ('Adobe Photoshop', 'Magento', 'Written'): 181,
#  ('Adobe Photoshop', 'Spoken', 'Written'): 181,
#  ('CSS', 'HTML', 'JavaScript'): 38,
#  ('CSS', 'HTML', 'PHP'): 219,
#  ('CSS', 'HTML', 'SEO'): 181,
#  ('CSS', 'HTML', 'Search Engine Optimization'): 181,
#  ('CSS', 'JavaScript', 'PHP'): 38,
#  ('CSS', 'PHP', 'SEO'): 181,
#  ('CSS', 'PHP', 'Search Engine Optimization'): 181,
#  ('CSS', 'SEO', 'Search Engine Optimization'): 181,
#  ('Data Structures', 'Java', 'Python'): 181,
#  ('English Proficiency', 'Hindi Proficiency', 'Spoken'): 197,
#  ('English Proficiency', 'Hindi Proficiency', 'Telugu Proficiency'): 181,
#  ('English Proficiency', 'MS Excel', 'MS Office'): 362,
#  ('English Proficiency', 'MS Excel', 'MS PowerPoint'): 187,
#  ('English Proficiency', 'MS Excel', 'MS Word'): 187,
#  ('English Proficiency', 'MS Excel', 'Spoken'): 374,
#  ('English Proficiency', 'MS Excel', 'Written'): 374,
#  ('English Proficiency', 'MS Office', 'MS PowerPoint'): 181,
#  ('English Proficiency', 'MS Office', 'MS Word'): 181,
#  ('English Proficiency', 'MS Office', 'Magento'): 181,
#  ('English Proficiency', 'MS Office', 'Spoken'): 597,
#  ('English Proficiency', 'MS Office', 'Written'): 555,
#  ('English Proficiency', 'MS PowerPoint', 'MS Word'): 187,
#  ('English Proficiency', 'MS PowerPoint', 'Spoken'): 187,
#  ('English Proficiency', 'MS PowerPoint', 'Written'): 187,
#  ('English Proficiency', 'MS Word', 'Spoken'): 187,
#  ('English Proficiency', 'MS Word', 'Written'): 187,
#  ('English Proficiency', 'Magento', 'Spoken'): 181,
#  ('English Proficiency', 'Magento', 'Written'): 181,
#  ('English Proficiency', 'SEO', 'Search Engine Optimization'): 181,
#  ('English Proficiency', 'SEO', 'Spoken'): 181,
#  ('English Proficiency', 'SEO', 'Written'): 181,
#  ('English Proficiency', 'Search Engine Optimization', 'Spoken'): 181,
#  ('English Proficiency', 'Search Engine Optimization', 'Written'): 181,
#  ('English Proficiency', 'Spoken', 'Telugu Proficiency'): 181,
#  ('English Proficiency', 'Spoken', 'Written'): 754,
#  ('HTML', 'JavaScript', 'PHP'): 38,
#  ('HTML', 'PHP', 'SEO'): 181,
#  ('HTML', 'PHP', 'Search Engine Optimization'): 181,
#  ('HTML', 'SEO', 'Search Engine Optimization'): 181,
#  ('Hindi Proficiency', 'Spoken', 'Telugu Proficiency'): 181,
#  ('MS Excel', 'MS Office', 'MS PowerPoint'): 393,
#  ('MS Excel', 'MS Office', 'MS Word'): 377,
#  ('MS Excel', 'MS Office', 'SEO'): 180,
#  ('MS Excel', 'MS Office', 'Search Engine Optimization'): 180,
#  ('MS Excel', 'MS Office', 'Spoken'): 362,
#  ('MS Excel', 'MS Office', 'Written'): 362,
#  ('MS Excel', 'MS PowerPoint', 'MS Word'): 367,
#  ('MS Excel', 'MS PowerPoint', 'SEO'): 180,
#  ('MS Excel', 'MS PowerPoint', 'Search Engine Optimization'): 180,
#  ('MS Excel', 'MS PowerPoint', 'Spoken'): 187,
#  ('MS Excel', 'MS PowerPoint', 'Written'): 187,
#  ('MS Excel', 'MS Word', 'SEO'): 180,
#  ('MS Excel', 'MS Word', 'Search Engine Optimization'): 180,
#  ('MS Excel', 'MS Word', 'Spoken'): 187,
#  ('MS Excel', 'MS Word', 'Written'): 187,
#  ('MS Excel', 'SEO', 'Search Engine Optimization'): 196,
#  ('MS Excel', 'Spoken', 'Written'): 374,
#  ('MS Office', 'MS PowerPoint', 'MS Word'): 361,
#  ('MS Office', 'MS PowerPoint', 'SEO'): 180,
#  ('MS Office', 'MS PowerPoint', 'Search Engine Optimization'): 180,
#  ('MS Office', 'MS PowerPoint', 'Spoken'): 181,
#  ('MS Office', 'MS PowerPoint', 'Written'): 181,
#  ('MS Office', 'MS Word', 'SEO'): 180,
#  ('MS Office', 'MS Word', 'Search Engine Optimization'): 180,
#  ('MS Office', 'MS Word', 'Spoken'): 181,
#  ('MS Office', 'MS Word', 'Written'): 181,
#  ('MS Office', 'Magento', 'Spoken'): 181,
#  ('MS Office', 'Magento', 'Written'): 181,
#  ('MS Office', 'SEO', 'Search Engine Optimization'): 180,
#  ('MS Office', 'Spoken', 'Written'): 549,
#  ('MS PowerPoint', 'MS Word', 'SEO'): 180,
#  ('MS PowerPoint', 'MS Word', 'Search Engine Optimization'): 180,
#  ('MS PowerPoint', 'MS Word', 'Spoken'): 187,
#  ('MS PowerPoint', 'MS Word', 'Written'): 187,
#  ('MS PowerPoint', 'SEO', 'Search Engine Optimization'): 180,
#  ('MS PowerPoint', 'Spoken', 'Written'): 187,
#  ('MS Word', 'SEO', 'Search Engine Optimization'): 180,
#  ('MS Word', 'Spoken', 'Written'): 187,
#  ('Magento', 'Spoken', 'Written'): 181,
#  ('PHP', 'SEO', 'Search Engine Optimization'): 181,
#  ('SEO', 'Search Engine Optimization', 'Spoken'): 181,
#  ('SEO', 'Search Engine Optimization', 'Written'): 181,
#  ('SEO', 'Spoken', 'Written'): 181,
#  ('Search Engine Optimization', 'Spoken', 'Written'): 181}

# %%
itemlist = {**l1, **l2, **l3}
#print(itemlist)

# %%
def support_count(itemset, itemlist):
    return itemlist[itemset]

sets = []
for iter1 in list(l3.keys()):
    subsets = list(itertools.combinations(iter1, 2))
    sets.append(subsets)

# %%
result = []
list_l3 = list(l3.keys())
for i in range(0, len(list_l3)):
    for iter1 in sets[i]:
        a = iter1
        b = set(list_l3[i]) - set(iter1)
        confidence = (support_count(list_l3[i], itemlist)/support_count(iter1, itemlist))*100
        if(confidence>60):
            print("Confidence{}->{} = ".format(a,b), confidence)
            result.append([a,b])
# Out:
# Confidence('Adobe After Effects', 'Adobe Illustrator')->{'Adobe Photoshop'} =  100.0
# Confidence('Adobe After Effects', 'Adobe Photoshop')->{'Adobe Illustrator'} =  100.0
# Confidence('Adobe Dreamweaver', 'CSS')->{'HTML'} =  100.0
# Confidence('Adobe Dreamweaver', 'HTML')->{'CSS'} =  100.0
# Confidence('CSS', 'HTML')->{'Adobe Dreamweaver'} =  80.44444444444444
# Confidence('Adobe Dreamweaver', 'CSS')->{'PHP'} =  100.0
# Confidence('Adobe Dreamweaver', 'PHP')->{'CSS'} =  100.0
# Confidence('CSS', 'PHP')->{'Adobe Dreamweaver'} =  82.64840182648402
# Confidence('Adobe Dreamweaver', 'CSS')->{'SEO'} =  100.0
# Confidence('Adobe Dreamweaver', 'SEO')->{'CSS'} =  100.0
# Confidence('CSS', 'SEO')->{'Adobe Dreamweaver'} =  100.0
# Confidence('Adobe Dreamweaver', 'CSS')->{'Search Engine Optimization'} =  100.0
# Confidence('Adobe Dreamweaver', 'Search Engine Optimization')->{'CSS'} =  100.0
# Confidence('CSS', 'Search Engine Optimization')->{'Adobe Dreamweaver'} =  100.0
# Confidence('Adobe Dreamweaver', 'HTML')->{'PHP'} =  100.0
# Confidence('Adobe Dreamweaver', 'PHP')->{'HTML'} =  100.0
# Confidence('HTML', 'PHP')->{'Adobe Dreamweaver'} =  82.64840182648402
# Confidence('Adobe Dreamweaver', 'HTML')->{'SEO'} =  100.0
# Confidence('Adobe Dreamweaver', 'SEO')->{'HTML'} =  100.0
# Confidence('HTML', 'SEO')->{'Adobe Dreamweaver'} =  100.0
# Confidence('Adobe Dreamweaver', 'HTML')->{'Search Engine Optimization'} =  100.0
# Confidence('Adobe Dreamweaver', 'Search Engine Optimization')->{'HTML'} =  100.0
# Confidence('HTML', 'Search Engine Optimization')->{'Adobe Dreamweaver'} =  100.0
# Confidence('Adobe Dreamweaver', 'PHP')->{'SEO'} =  100.0
# Confidence('Adobe Dreamweaver', 'SEO')->{'PHP'} =  100.0
# Confidence('PHP', 'SEO')->{'Adobe Dreamweaver'} =  100.0
# Confidence('Adobe Dreamweaver', 'PHP')->{'Search Engine Optimization'} =  100.0
# Confidence('Adobe Dreamweaver', 'Search Engine Optimization')->{'PHP'} =  100.0
# Confidence('PHP', 'Search Engine Optimization')->{'Adobe Dreamweaver'} =  100.0
# Confidence('Adobe Dreamweaver', 'SEO')->{'Search Engine Optimization'} =  100.0
# Confidence('Adobe Dreamweaver', 'Search Engine Optimization')->{'SEO'} =  100.0
# Confidence('Adobe Illustrator', 'Adobe XD')->{'Adobe Photoshop'} =  100.0
# Confidence('Adobe Photoshop', 'Adobe XD')->{'Adobe Illustrator'} =  100.0
# Confidence('Adobe Illustrator', 'Video Editing')->{'Adobe Photoshop'} =  100.0
# Confidence('Adobe Photoshop', 'Video Editing')->{'Adobe Illustrator'} =  100.0
# Confidence('Adobe Photoshop', 'English Proficiency')->{'MS Office'} =  100.0
# Confidence('Adobe Photoshop', 'MS Office')->{'English Proficiency'} =  100.0
# Confidence('Adobe Photoshop', 'English Proficiency')->{'Magento'} =  100.0
# Confidence('Adobe Photoshop', 'Magento')->{'English Proficiency'} =  100.0
# Confidence('English Proficiency', 'Magento')->{'Adobe Photoshop'} =  100.0
# Confidence('Adobe Photoshop', 'English Proficiency')->{'Spoken'} =  100.0
# Confidence('Adobe Photoshop', 'Spoken')->{'English Proficiency'} =  100.0
# Confidence('Adobe Photoshop', 'English Proficiency')->{'Written'} =  100.0
# Confidence('Adobe Photoshop', 'Written')->{'English Proficiency'} =  100.0
# Confidence('Adobe Photoshop', 'MS Office')->{'Magento'} =  100.0
# Confidence('Adobe Photoshop', 'Magento')->{'MS Office'} =  100.0
# Confidence('MS Office', 'Magento')->{'Adobe Photoshop'} =  100.0
# Confidence('Adobe Photoshop', 'MS Office')->{'Spoken'} =  100.0
# Confidence('Adobe Photoshop', 'Spoken')->{'MS Office'} =  100.0
# Confidence('Adobe Photoshop', 'MS Office')->{'Written'} =  100.0
# Confidence('Adobe Photoshop', 'Written')->{'MS Office'} =  100.0
# Confidence('Adobe Photoshop', 'Magento')->{'Spoken'} =  100.0
# Confidence('Adobe Photoshop', 'Spoken')->{'Magento'} =  100.0
# Confidence('Magento', 'Spoken')->{'Adobe Photoshop'} =  100.0
# Confidence('Adobe Photoshop', 'Magento')->{'Written'} =  100.0
# Confidence('Adobe Photoshop', 'Written')->{'Magento'} =  100.0
# Confidence('Magento', 'Written')->{'Adobe Photoshop'} =  100.0
# Confidence('Adobe Photoshop', 'Spoken')->{'Written'} =  100.0
# Confidence('Adobe Photoshop', 'Written')->{'Spoken'} =  100.0
# Confidence('CSS', 'JavaScript')->{'HTML'} =  100.0
# Confidence('HTML', 'JavaScript')->{'CSS'} =  100.0
# Confidence('CSS', 'HTML')->{'PHP'} =  97.33333333333334
# Confidence('CSS', 'PHP')->{'HTML'} =  100.0
# Confidence('HTML', 'PHP')->{'CSS'} =  100.0
# Confidence('CSS', 'HTML')->{'SEO'} =  80.44444444444444
# Confidence('CSS', 'SEO')->{'HTML'} =  100.0
# Confidence('HTML', 'SEO')->{'CSS'} =  100.0
# Confidence('CSS', 'HTML')->{'Search Engine Optimization'} =  80.44444444444444
# Confidence('CSS', 'Search Engine Optimization')->{'HTML'} =  100.0
# Confidence('HTML', 'Search Engine Optimization')->{'CSS'} =  100.0
# Confidence('CSS', 'JavaScript')->{'PHP'} =  100.0
# Confidence('JavaScript', 'PHP')->{'CSS'} =  86.36363636363636
# Confidence('CSS', 'PHP')->{'SEO'} =  82.64840182648402
# Confidence('CSS', 'SEO')->{'PHP'} =  100.0
# Confidence('PHP', 'SEO')->{'CSS'} =  100.0
# Confidence('CSS', 'PHP')->{'Search Engine Optimization'} =  82.64840182648402
# Confidence('CSS', 'Search Engine Optimization')->{'PHP'} =  100.0
# Confidence('PHP', 'Search Engine Optimization')->{'CSS'} =  100.0
# Confidence('CSS', 'SEO')->{'Search Engine Optimization'} =  100.0
# Confidence('CSS', 'Search Engine Optimization')->{'SEO'} =  100.0
# Confidence('Data Structures', 'Java')->{'Python'} =  100.0
# Confidence('Data Structures', 'Python')->{'Java'} =  100.0
# Confidence('Java', 'Python')->{'Data Structures'} =  100.0
# Confidence('English Proficiency', 'Hindi Proficiency')->{'Spoken'} =  100.0
# Confidence('Hindi Proficiency', 'Spoken')->{'English Proficiency'} =  100.0
# Confidence('English Proficiency', 'Hindi Proficiency')->{'Telugu Proficiency'} =  91.87817258883248
# Confidence('English Proficiency', 'Telugu Proficiency')->{'Hindi Proficiency'} =  100.0
# Confidence('Hindi Proficiency', 'Telugu Proficiency')->{'English Proficiency'} =  100.0
# Confidence('English Proficiency', 'MS Excel')->{'MS Office'} =  96.79144385026738
# Confidence('English Proficiency', 'MS Office')->{'MS Excel'} =  60.033167495854066
# Confidence('MS Excel', 'MS Office')->{'English Proficiency'} =  60.738255033557046
# Confidence('English Proficiency', 'MS PowerPoint')->{'MS Excel'} =  100.0
# Confidence('English Proficiency', 'MS Word')->{'MS Excel'} =  100.0
# Confidence('English Proficiency', 'MS Excel')->{'Spoken'} =  100.0
# Confidence('MS Excel', 'Spoken')->{'English Proficiency'} =  100.0
# Confidence('English Proficiency', 'MS Excel')->{'Written'} =  100.0
# Confidence('MS Excel', 'Written')->{'English Proficiency'} =  100.0
# Confidence('English Proficiency', 'MS PowerPoint')->{'MS Office'} =  96.79144385026738
# Confidence('English Proficiency', 'MS Word')->{'MS Office'} =  96.79144385026738
# Confidence('English Proficiency', 'Magento')->{'MS Office'} =  100.0
# Confidence('MS Office', 'Magento')->{'English Proficiency'} =  100.0
# Confidence('English Proficiency', 'MS Office')->{'Spoken'} =  99.00497512437812
# Confidence('MS Office', 'Spoken')->{'English Proficiency'} =  100.0
# Confidence('English Proficiency', 'MS Office')->{'Written'} =  92.03980099502488
# Confidence('MS Office', 'Written')->{'English Proficiency'} =  100.0
# Confidence('English Proficiency', 'MS PowerPoint')->{'MS Word'} =  100.0
# Confidence('English Proficiency', 'MS Word')->{'MS PowerPoint'} =  100.0
# Confidence('English Proficiency', 'MS PowerPoint')->{'Spoken'} =  100.0
# Confidence('MS PowerPoint', 'Spoken')->{'English Proficiency'} =  100.0
# Confidence('English Proficiency', 'MS PowerPoint')->{'Written'} =  100.0
# Confidence('MS PowerPoint', 'Written')->{'English Proficiency'} =  100.0
# Confidence('English Proficiency', 'MS Word')->{'Spoken'} =  100.0
# Confidence('MS Word', 'Spoken')->{'English Proficiency'} =  100.0
# Confidence('English Proficiency', 'MS Word')->{'Written'} =  100.0
# Confidence('MS Word', 'Written')->{'English Proficiency'} =  100.0
# Confidence('English Proficiency', 'Magento')->{'Spoken'} =  100.0
# Confidence('Magento', 'Spoken')->{'English Proficiency'} =  100.0
# Confidence('English Proficiency', 'Magento')->{'Written'} =  100.0
# Confidence('Magento', 'Written')->{'English Proficiency'} =  100.0
# Confidence('English Proficiency', 'SEO')->{'Search Engine Optimization'} =  100.0
# Confidence('English Proficiency', 'Search Engine Optimization')->{'SEO'} =  100.0
# Confidence('English Proficiency', 'SEO')->{'Spoken'} =  100.0
# Confidence('SEO', 'Spoken')->{'English Proficiency'} =  100.0
# Confidence('English Proficiency', 'SEO')->{'Written'} =  100.0
# Confidence('SEO', 'Written')->{'English Proficiency'} =  100.0
# Confidence('English Proficiency', 'Search Engine Optimization')->{'Spoken'} =  100.0
# Confidence('Search Engine Optimization', 'Spoken')->{'English Proficiency'} =  100.0
# Confidence('English Proficiency', 'Search Engine Optimization')->{'Written'} =  100.0
# Confidence('Search Engine Optimization', 'Written')->{'English Proficiency'} =  100.0
# Confidence('English Proficiency', 'Telugu Proficiency')->{'Spoken'} =  100.0
# Confidence('Spoken', 'Telugu Proficiency')->{'English Proficiency'} =  100.0
# Confidence('English Proficiency', 'Spoken')->{'Written'} =  75.77889447236181
# Confidence('English Proficiency', 'Written')->{'Spoken'} =  67.20142602495544
# Confidence('Spoken', 'Written')->{'English Proficiency'} =  100.0
# Confidence('HTML', 'JavaScript')->{'PHP'} =  100.0
# Confidence('JavaScript', 'PHP')->{'HTML'} =  86.36363636363636
# Confidence('HTML', 'PHP')->{'SEO'} =  82.64840182648402
# Confidence('HTML', 'SEO')->{'PHP'} =  100.0
# Confidence('PHP', 'SEO')->{'HTML'} =  100.0
# Confidence('HTML', 'PHP')->{'Search Engine Optimization'} =  82.64840182648402
# Confidence('HTML', 'Search Engine Optimization')->{'PHP'} =  100.0
# Confidence('PHP', 'Search Engine Optimization')->{'HTML'} =  100.0
# Confidence('HTML', 'SEO')->{'Search Engine Optimization'} =  100.0
# Confidence('HTML', 'Search Engine Optimization')->{'SEO'} =  100.0
# Confidence('Hindi Proficiency', 'Spoken')->{'Telugu Proficiency'} =  91.87817258883248
# Confidence('Hindi Proficiency', 'Telugu Proficiency')->{'Spoken'} =  100.0
# Confidence('Spoken', 'Telugu Proficiency')->{'Hindi Proficiency'} =  100.0
# Confidence('MS Excel', 'MS Office')->{'MS PowerPoint'} =  65.93959731543623
# Confidence('MS Excel', 'MS PowerPoint')->{'MS Office'} =  94.6987951807229
# Confidence('MS Office', 'MS PowerPoint')->{'MS Excel'} =  100.0
# Confidence('MS Excel', 'MS Office')->{'MS Word'} =  63.25503355704698
# Confidence('MS Excel', 'MS Word')->{'MS Office'} =  98.43342036553526
# Confidence('MS Office', 'MS Word')->{'MS Excel'} =  100.0
# Confidence('MS Excel', 'SEO')->{'MS Office'} =  91.83673469387756
# Confidence('MS Office', 'SEO')->{'MS Excel'} =  100.0
# Confidence('MS Excel', 'Search Engine Optimization')->{'MS Office'} =  91.83673469387756
# Confidence('MS Office', 'Search Engine Optimization')->{'MS Excel'} =  100.0
# Confidence('MS Excel', 'MS Office')->{'Spoken'} =  60.738255033557046
# Confidence('MS Excel', 'Spoken')->{'MS Office'} =  96.79144385026738
# Confidence('MS Office', 'Spoken')->{'MS Excel'} =  60.63651591289783
# Confidence('MS Excel', 'MS Office')->{'Written'} =  60.738255033557046
# Confidence('MS Excel', 'Written')->{'MS Office'} =  96.79144385026738
# Confidence('MS Office', 'Written')->{'MS Excel'} =  65.22522522522523
# Confidence('MS Excel', 'MS PowerPoint')->{'MS Word'} =  88.43373493975903
# Confidence('MS Excel', 'MS Word')->{'MS PowerPoint'} =  95.822454308094
# Confidence('MS PowerPoint', 'MS Word')->{'MS Excel'} =  100.0
# Confidence('MS Excel', 'SEO')->{'MS PowerPoint'} =  91.83673469387756
# Confidence('MS PowerPoint', 'SEO')->{'MS Excel'} =  100.0
# Confidence('MS Excel', 'Search Engine Optimization')->{'MS PowerPoint'} =  91.83673469387756
# Confidence('MS PowerPoint', 'Search Engine Optimization')->{'MS Excel'} =  100.0
# Confidence('MS PowerPoint', 'Spoken')->{'MS Excel'} =  100.0
# Confidence('MS PowerPoint', 'Written')->{'MS Excel'} =  100.0
# Confidence('MS Excel', 'SEO')->{'MS Word'} =  91.83673469387756
# Confidence('MS Word', 'SEO')->{'MS Excel'} =  100.0
# Confidence('MS Excel', 'Search Engine Optimization')->{'MS Word'} =  91.83673469387756
# Confidence('MS Word', 'Search Engine Optimization')->{'MS Excel'} =  100.0
# Confidence('MS Word', 'Spoken')->{'MS Excel'} =  100.0
# Confidence('MS Word', 'Written')->{'MS Excel'} =  100.0
# Confidence('MS Excel', 'SEO')->{'Search Engine Optimization'} =  100.0
# Confidence('MS Excel', 'Search Engine Optimization')->{'SEO'} =  100.0
# Confidence('MS Excel', 'Spoken')->{'Written'} =  100.0
# Confidence('MS Excel', 'Written')->{'Spoken'} =  100.0
# Confidence('MS Office', 'MS PowerPoint')->{'MS Word'} =  91.85750636132316
# Confidence('MS Office', 'MS Word')->{'MS PowerPoint'} =  95.75596816976127
# Confidence('MS PowerPoint', 'MS Word')->{'MS Office'} =  98.36512261580381
# Confidence('MS Office', 'SEO')->{'MS PowerPoint'} =  100.0
# Confidence('MS PowerPoint', 'SEO')->{'MS Office'} =  100.0
# Confidence('MS Office', 'Search Engine Optimization')->{'MS PowerPoint'} =  100.0
# Confidence('MS PowerPoint', 'Search Engine Optimization')->{'MS Office'} =  100.0
# Confidence('MS PowerPoint', 'Spoken')->{'MS Office'} =  96.79144385026738
# Confidence('MS PowerPoint', 'Written')->{'MS Office'} =  96.79144385026738
# Confidence('MS Office', 'SEO')->{'MS Word'} =  100.0
# Confidence('MS Word', 'SEO')->{'MS Office'} =  100.0
# Confidence('MS Office', 'Search Engine Optimization')->{'MS Word'} =  100.0
# Confidence('MS Word', 'Search Engine Optimization')->{'MS Office'} =  100.0
# Confidence('MS Word', 'Spoken')->{'MS Office'} =  96.79144385026738
# Confidence('MS Word', 'Written')->{'MS Office'} =  96.79144385026738
# Confidence('MS Office', 'Magento')->{'Spoken'} =  100.0
# Confidence('Magento', 'Spoken')->{'MS Office'} =  100.0
# Confidence('MS Office', 'Magento')->{'Written'} =  100.0
# Confidence('Magento', 'Written')->{'MS Office'} =  100.0
# Confidence('MS Office', 'SEO')->{'Search Engine Optimization'} =  100.0
# Confidence('MS Office', 'Search Engine Optimization')->{'SEO'} =  100.0
# Confidence('MS Office', 'Spoken')->{'Written'} =  91.95979899497488
# Confidence('MS Office', 'Written')->{'Spoken'} =  98.91891891891892
# Confidence('Spoken', 'Written')->{'MS Office'} =  72.81167108753316
# Confidence('MS PowerPoint', 'SEO')->{'MS Word'} =  100.0
# Confidence('MS Word', 'SEO')->{'MS PowerPoint'} =  100.0
# Confidence('MS PowerPoint', 'Search Engine Optimization')->{'MS Word'} =  100.0
# Confidence('MS Word', 'Search Engine Optimization')->{'MS PowerPoint'} =  100.0
# Confidence('MS PowerPoint', 'Spoken')->{'MS Word'} =  100.0
# Confidence('MS Word', 'Spoken')->{'MS PowerPoint'} =  100.0
# Confidence('MS PowerPoint', 'Written')->{'MS Word'} =  100.0
# Confidence('MS Word', 'Written')->{'MS PowerPoint'} =  100.0
# Confidence('MS PowerPoint', 'SEO')->{'Search Engine Optimization'} =  100.0
# Confidence('MS PowerPoint', 'Search Engine Optimization')->{'SEO'} =  100.0
# Confidence('MS PowerPoint', 'Spoken')->{'Written'} =  100.0
# Confidence('MS PowerPoint', 'Written')->{'Spoken'} =  100.0
# Confidence('MS Word', 'SEO')->{'Search Engine Optimization'} =  100.0
# Confidence('MS Word', 'Search Engine Optimization')->{'SEO'} =  100.0
# Confidence('MS Word', 'Spoken')->{'Written'} =  100.0
# Confidence('MS Word', 'Written')->{'Spoken'} =  100.0
# Confidence('Magento', 'Spoken')->{'Written'} =  100.0
# Confidence('Magento', 'Written')->{'Spoken'} =  100.0
# Confidence('PHP', 'SEO')->{'Search Engine Optimization'} =  100.0
# Confidence('PHP', 'Search Engine Optimization')->{'SEO'} =  100.0
# Confidence('SEO', 'Spoken')->{'Search Engine Optimization'} =  100.0
# Confidence('Search Engine Optimization', 'Spoken')->{'SEO'} =  100.0
# Confidence('SEO', 'Written')->{'Search Engine Optimization'} =  100.0
# Confidence('Search Engine Optimization', 'Written')->{'SEO'} =  100.0
# Confidence('SEO', 'Spoken')->{'Written'} =  100.0
# Confidence('SEO', 'Written')->{'Spoken'} =  100.0
# Confidence('Search Engine Optimization', 'Spoken')->{'Written'} =  100.0
# Confidence('Search Engine Optimization', 'Written')->{'Spoken'} =  100.0

# %%
len(result)
# Out:
# 234

# %%
result[9]
# Out:
# [('Adobe Dreamweaver', 'SEO'), {'CSS'}]

# %%
result[9][0]
# Out:
# ('Adobe Dreamweaver', 'SEO')

# %%
result[9][1]
# Out:
# {'CSS'}
